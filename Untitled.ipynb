# %%
import json
import re
from collections import defaultdict

# --- Load properties from JSON file ---
try:
    with open("property_data.json", "r") as f:
        properties_data = json.load(f)
except FileNotFoundError:
    print("Error: 'property_data.json' not found. Please ensure the file exists.")
    properties_data = []
except json.JSONDecodeError:
    print("Error: Could not decode 'property_data.json'. Please check its format.")
    properties_data = []


# --- Normalization helpers ---
def normalize(text):
    return str(text).lower().strip().replace(" ", "_")

def get_numeric_value(value):
    if not value:
        return None
    match = re.search(r"\d+", str(value))
    return int(match.group()) if match else None


# --- Filtering logic ---
def filter_properties(user_input, data):
    user_input = user_input.lower()
    results = data

    # Rent filtering
    rent_match = re.search(r"rent\s*(below|under|less than|above|over|greater than)?\s*(\d+)", user_input)
    if rent_match:
        direction = rent_match.group(1)
        amount = int(rent_match.group(2))
        if direction in ["below", "under", "less than"]:
            results = [p for p in results if get_numeric_value(p.get("Rent_Price")) and get_numeric_value(p.get("Rent_Price")) < amount]
        elif direction in ["above", "over", "greater than"]:
            results = [p for p in results if get_numeric_value(p.get("Rent_Price")) and get_numeric_value(p.get("Rent_Price")) > amount]
        else:
            results = [p for p in results if get_numeric_value(p.get("Rent_Price")) == amount]

    # Bedrooms (e.g., 2 bhk, 3 bedrooms)
    bhk_match = re.search(r"(\d+)\s*(bhk|bed(room)?s?)", user_input)
    if bhk_match:
        bhk = int(bhk_match.group(1))
        results = [p for p in results if get_numeric_value(p.get("Bedrooms")) == bhk]

    # Area
    for p in data:
        if "area" in user_input and p.get("Area", "").lower() in user_input:
            results = [prop for prop in results if prop.get("Area", "").lower() in user_input]

    # Zone
    for p in data:
        if "zone" in user_input and p.get("Zone", "").lower() in user_input:
            results = [prop for prop in results if prop.get("Zone", "").lower() in user_input]

    # Facilities
    if "parking" in user_input or "car" in user_input:
        results = [p for p in results if p.get("Facilities", {}).get("parking", 0) == 1]
    if "gym" in user_input:
        results = [p for p in results if p.get("Facilities", {}).get("gym", 0) == 1]
    if "swimming" in user_input:
        results = [p for p in results if p.get("Facilities", {}).get("swimming_pool", 0) == 1]

    return results


# --- Format results ---
def format_property(prop):
    return (
        f"🏠 ID: {prop.get('property_id', 'N/A')} | Rent: ₹{prop.get('Rent_Price', 'N/A')} | "
        f"{prop.get('Bedrooms', 'N/A')} BHK | {prop.get('Size_In_Sqft', 'Unknown')} sqft | "
        f"Area: {prop.get('Area', 'N/A')} | Zone: {prop.get('Zone', 'N/A')}"
    )


# --- Chatbot ---
def chatbot_response():
    print("🤖 Welcome to Property Chatbot!")
    print("You can ask things like:")
    print("- show me 2 bhk flats in Andheri with rent below 20000")
    print("- find flats in zone west with gym and swimming pool")
    print("- property with parking in Bandra")
    print("Type 'exit' to quit.\n")

    while True:
        user_input = input("You: ").strip().lower()
        if user_input == "exit":
            print("Goodbye 👋")
            break

        results = filter_properties(user_input, properties_data)

        if not results:
            print("❌ No properties found matching your query.")
        else:
            print(f"✅ Found {len(results)} property(s):\n")
            for prop in results[:10]:  # Show only first 10
                print(format_property(prop))
            print("-" * 40)


if __name__ == "__main__":
    chatbot_response()
# Out:
# 🤖 Welcome to Property Chatbot!
# You can ask things like:
# - show me 2 bhk flats in Andheri with rent below 20000
# - find flats in zone west with gym and swimming pool
# - property with parking in Bandra
# Type 'exit' to quit.
# You:  i want 800 sqft
# ✅ Found 1000 property(s):
#
# 🏠 ID: Property_1 | Rent: ₹10000.0 | 1 BHK | Total Area 800 .sqft  sqft | Area: shatabdisquare | Zone: South Zone
# 🏠 ID: Property_2 | Rent: ₹8000.0 | 1 BHK | Total Area 700 .sqft  sqft | Area: manewada | Zone: South Zone
# 🏠 ID: Property_3 | Rent: ₹6000.0 | 1 BHK | Total Area 1000.sqft  sqft | Area: hudkeswar | Zone: South Zone
# 🏠 ID: Property_4 | Rent: ₹4000.0 | 2 BHK | Total Area 500 .sqft  sqft | Area: manish nagar | Zone: South Zone
# 🏠 ID: Property_5 | Rent: ₹8500.0 | 1 BHK | Total Area 525.sqft  sqft | Area: beltarodi | Zone: South Zone
# 🏠 ID: Property_6 | Rent: ₹7000.0 | 2 BHK | Total Area 750.sqft  sqft | Area: mahal | Zone: East Zone
# 🏠 ID: Property_7 | Rent: ₹17000.0 | 3 BHK | Total Area 1300.sqft  sqft | Area: manewada | Zone: South Zone
# 🏠 ID: Property_8 | Rent: ₹20000.0 | 3 BHK | Total Area  1500.sqft  sqft | Area: manish nagar | Zone: South Zone
# 🏠 ID: Property_9 | Rent: ₹17000.0 | 3 BHK | Total Area 1300.sqft  sqft | Area: manewada | Zone: South Zone
# 🏠 ID: Property_10 | Rent: ₹20000.0 | 3 BHK | Total Area 1400.sqft  sqft | Area: besa | Zone: South Zone
# ----------------------------------------
# You:  exit
# Goodbye 👋

# %%
import json
import re
from collections import defaultdict

# --- Load properties from JSON file ---
try:
    with open("property_data.json", "r") as f:
        properties_data = json.load(f)
except FileNotFoundError:
    print("Error: 'property_data.json' not found. Please ensure the file exists.")
    properties_data = []
except json.JSONDecodeError:
    print("Error: Could not decode 'property_data.json'. Please check its format.")
    properties_data = []

# --- Helper functions for normalization ---
def normalize_area_name(area_name):
    return str(area_name).replace(" ", "").lower().strip()

def normalize_zone_name(zone_name):
    return str(zone_name).replace(" ", "").lower().strip()

def normalize_facility_name(facility_name):
    return str(facility_name).replace(" ", "_").lower().strip()

def normalize_amenity_name(name):
    return str(name).replace(" ", "_").lower().strip()

def normalize_room_name(room_name):
    return str(room_name).replace(" ", "").lower().strip()

def normalize_property_type_name(prop_type):
    return str(prop_type).lower().strip()

def get_numeric_value(value):
    """Extract integer from strings like '800 sqft', '10 years', etc.
        Returns None if no number is found."""
    if not value:
        return None
    match = re.search(r"\d+", str(value))
    return int(match.group()) if match else None


# --- Dynamically get all unique values from the dataset ---
ALL_AREAS = sorted(
    list(set(normalize_area_name(p.get("Area", "N/A")) for p in properties_data))
)

ALL_ZONES = sorted(
    list(set(normalize_zone_name(p.get("Zone", "N/A")) for p in properties_data))
)

ALL_FACILITIES = []
for p in properties_data:
    if "Facilities" in p and isinstance(p["Facilities"], dict):
        ALL_FACILITIES = sorted(list(p["Facilities"].keys()))
        break

ALL_NEARBY_AMENITIES = []
for p in properties_data:
    if "Nearby_Amenities" in p and isinstance(p["Nearby_Amenities"], dict):
        ALL_NEARBY_AMENITIES = sorted(list(p["Nearby_Amenities"].keys()))
        break

ALL_ROOM_TYPES = sorted(
    list(set(normalize_room_name(p.get("Room_Details", {}).get("Rooms", "N/A"))
             for p in properties_data if p.get("Room_Details", {}).get("Rooms")))
)

ALL_PROPERTY_TYPES = sorted(
    list(set(normalize_property_type_name(p.get("Room_Details", {}).get("Type", "N/A"))
             for p in properties_data if p.get("Room_Details", {}).get("Type")))
)



# --- Filtering logic ---
def filter_properties(user_input, field, data):
    filtered_properties = []

    # Map search field to the actual key in properties_data
    data_field_map = {
        "size": "Size_In_Sqft", "carpet": "Carpet_Area_Sqft", "age": "Property_Age", "brokerage": "Brokerage",
        "furnishing": "Furnishing_Status", "amenities": "Number_Of_Amenities", "security": "Security_Deposite", "rent": "Rent_Price",
        "area": "Area", "zone": "Zone", "bedrooms": "Bedrooms", "bathrooms": "Bathrooms", "balcony": "Balcony",
        "floor_no": "Floor_No", "total_floors": "Total_floors_In_Building", "maintenance": "Maintenance_Charge",
        "recommended_for": "Recommended_For", "water_supply": "Water_Supply_Type", "society_type": "Society_Type",
        "road_connectivity": "Road_Connectivity", "facilities": "Facilities", "nearby_amenities": "Nearby_Amenities",
        "room_type": "Room_Details", "property_type": "Room_Details", "id": "property_id"
    }
    data_field = data_field_map.get(field)
    if not data_field:
        return []

    # --- String fields ---
    normalized_user_input = user_input.lower().strip()
    if field in ["brokerage", "furnishing", "maintenance", "recommended_for", "water_supply", "society_type"]:
        filtered_properties = [p for p in data if str(p.get(data_field, "N/A")).lower() == normalized_user_input]

    elif field == "facilities":
        user_facilities = [normalize_facility_name(f) for f in user_input.split(',')]
        filtered_properties = [
            p for p in data 
            if all(
                any(normalize_facility_name(k) == fac and v == 1
                    for k, v in p.get("Facilities", {}).items())
                for fac in user_facilities
            )
        ]


    elif field == "nearby_amenities":
        user_facilities = [normalize_facility_name(f) for f in user_input.split(',')]
        filtered_properties = [
            p for p in data 
            if all(
                any(normalize_facility_name(k) == fac and v == 1
                    for k, v in p.get("Nearby_Amenities", {}).items())
                for fac in user_facilities
            )
        ]

    elif field == "room_type":
        filtered_properties = [p for p in data if normalize_room_name(p.get("Room_Details", {}).get("Rooms", "")) == normalized_user_input]

    elif field == "property_type":
        filtered_properties = [p for p in data if normalize_property_type_name(p.get("Room_Details", {}).get("Type", "")) == normalized_user_input]

    elif field == "area":
        filtered_properties = [p for p in data if normalize_area_name(p.get("Area", "N/A")) == normalize_area_name(user_input)]

    elif field == "zone":
        filtered_properties = [p for p in data if normalize_zone_name(p.get("Zone", "N/A")) == normalize_zone_name(user_input)]

    elif field == "id":
        filtered_properties = [p for p in data if str(p.get(data_field)) == user_input.strip()]

    else:
        try:
            val = get_numeric_value(user_input)
    
            if user_input.startswith("below"):
                filtered_properties = [
                    p for p in data
                    if get_numeric_value(p.get(data_field)) is not None 
                    and get_numeric_value(p.get(data_field)) < val
                ]
            elif user_input.startswith("above"):
                filtered_properties = [
                    p for p in data
                    if get_numeric_value(p.get(data_field)) is not None 
                    and get_numeric_value(p.get(data_field)) > val
                ]
            elif user_input.startswith("between"):
                nums = re.findall(r"\d+", user_input)
                if len(nums) == 2:
                    low, high = int(nums[0]), int(nums[1])
                    filtered_properties = [
                        p for p in data
                        if get_numeric_value(p.get(data_field)) is not None
                        and low <= get_numeric_value(p.get(data_field)) <= high
                    ]
            else:
                filtered_properties = [
                    p for p in data
                    if get_numeric_value(p.get(data_field)) == val
                ]
    
        except Exception:
            return []

    return filtered_properties

# --- Format results ---
def format_property(prop):
    property_id = prop.get('property_id', 'N/A')
    rent_price = prop.get('Rent_Price', 'N/A')
    size = prop.get('Size_In_Sqft', 'Unknown')
    carpet_area = prop.get('Carpet_Area_Sqft', 'Unknown')
    security_deposit = prop.get('Security_Deposite', 'N/A')
    brokerage = prop.get('Brokerage', 'N/A')
    furnishing_status = prop.get('Furnishing_Status', 'N/A')
    amenities = prop.get('Number_Of_Amenities',0)
    age = prop.get('Property_Age', 'Unknown')
    area = prop.get('Area', 'N/A')
    zone = prop.get('Zone', 'N/A')
    bedrooms = prop.get('Bedrooms', 'N/A')
    bathrooms = prop.get('Bathrooms', 'N/A')
    balcony = prop.get('Balcony', 'N/A')
    floor_no = prop.get('Floor_No', 'N/A')
    total_floors = prop.get('Total_floors_In_Building', 'N/A')
    maintenance = prop.get('Maintenance_Charge', 'N/A')
    recommended_for = prop.get('Recommended_For', 'N/A')
    water_supply = prop.get('Water_Supply_Type', 'N/A')
    society_type = prop.get('Society_Type', 'N/A')
    road_connectivity = prop.get('Road_Connectivity', 'N/A')
    facilities_list = [k.replace("_", " ").title() for k, v in prop.get("Facilities", {}).items() if v == 1]
    facilities = ', '.join(facilities_list) if facilities_list else 'None'
    nearby_amenities_list = [k.replace("_", " ").title() for k, v in prop.get("Nearby_Amenities", {}).items() if v == 1]
    nearby_amenities = ', '.join(nearby_amenities_list) if nearby_amenities_list else 'None'
    rooms = prop.get("Room_Details", {}).get("Rooms", "N/A")
    property_type = prop.get("Room_Details", {}).get("Type", "N/A")

    return (
        f"ID: {property_id} | Rent: ₹{rent_price} | Size: {size} sqft | Carpet Area: {carpet_area} sqft\n"
        f"Rooms: {rooms} | Property Type: {property_type} | Bedrooms: {bedrooms} | Bathrooms: {bathrooms} | Balcony: {balcony}\n"
        f"Furnishing: {furnishing_status} | Security Deposit: ₹{security_deposit} | Brokerage: {brokerage}\n"
        f"Amenities: {amenities}\n"
        f"Facilities: {facilities}\n"
        f"Nearby Amenities: {nearby_amenities}\n"
        f"Floor: {floor_no}/{total_floors} | Maintenance: {maintenance} | Recommended For: {recommended_for}\n"
        f"Water Supply: {water_supply} | Society: {society_type} | Road Connectivity: {road_connectivity} km\n"
        f"Age: {age} years | Area: {area} | Zone: {zone}\n"
        f"----------------------------------------"
    )

# --- Chatbot ---
def chatbot_response():
    print("Welcome to Property Search Chatbot!")
    print("\nSearch Options:")
    print(
        "1. Size (sqft)\n2. Carpet Area (sqft)\n3. Age of Property\n4. Brokerage (yes/no)\n5. Property ID (exact match)\n"
        "6. Amenities\n7. Furnishing Status\n8. Security Deposit\n9. Rent Price\n10. Area\n11. Zone\n"
        "12. Bedrooms\n13. Bathrooms\n14. Balcony\n15. Floor Number\n16. Total Floors\n17. Maintenance Charge\n"
        "18. Recommended For\n19. Water Supply Type\n20. Society Type\n21. Road Connectivity\n22. Facilities\n"
        "23. Nearby Amenities\n24. Room Type (e.g., 1 BHK)\n25. Property Type (e.g., Flat)\n"
    )
    print("💡 You can combine multiple search fields using '+'.")
    print("Example: 9+10 (Rent + Area)")
    print("For numeric values, you can use 'above 1000', 'below 5000', 'between 1000 and 5000'.")
    print("For facilities/amenities, separate multiple options with a comma (e.g., 'Gym,Lift').")
    print("Type 'exit' to quit.")

    CATEGORY_OPTIONS = {
    "brokerage": sorted(list(set(str(p.get("Brokerage", "N/A")).lower() for p in properties_data))),
    "furnishing": sorted(list(set(str(p.get("Furnishing_Status", "N/A")).lower() for p in properties_data))),
    "maintenance": sorted(list(set(str(p.get("Maintenance_Charge", "N/A")).lower() for p in properties_data))),
    "recommended_for": sorted(list(set(str(p.get("Recommended_For", "N/A")).lower() for p in properties_data))),
    "water_supply": sorted(list(set(str(p.get("Water_Supply_Type", "N/A")).lower() for p in properties_data))),
    "society_type": sorted(list(set(str(p.get("Society_Type", "N/A")).lower() for p in properties_data))),
    "area": ALL_AREAS,
    "zone": ALL_ZONES,
    "room_type": ALL_ROOM_TYPES,
    "property_type": ALL_PROPERTY_TYPES,
    "facilities": ALL_FACILITIES,
    "nearby_amenities": ALL_NEARBY_AMENITIES 
    }


    search_map = {
        "1": "size", "2": "carpet", "3": "age", "4": "brokerage", "5": "id", "6": "amenities", "7": "furnishing",
        "8": "security", "9": "rent", "10": "area", "11": "zone", "12": "bedrooms", "13": "bathrooms",
        "14": "balcony", "15": "floor_no", "16": "total_floors", "17": "maintenance", "18": "recommended_for",
        "19": "water_supply", "20": "society_type", "21": "road_connectivity", "22": "facilities", "23": "nearby_amenities",
        "24": "room_type", "25": "property_type"
    }
    
    while True:
        field_numbers = input("\nEnter the number(s) of search fields to combine (e.g., 9+10) or 'exit': ").strip().lower()
        if field_numbers == "exit":
            print("Goodbye!")
            break

        selected_fields = []
        is_valid_input = True
        for num in field_numbers.split('+'):
            num = num.strip()
            if num in search_map:
                selected_fields.append(search_map[num])
            else:
                print(f"❌ Invalid field number: '{num}'. Please use a valid number from the list.")
                is_valid_input = False
                break
        
        if not is_valid_input:
            continue

        combined_filters = {}
        for field in selected_fields:
            if field in CATEGORY_OPTIONS and CATEGORY_OPTIONS[field]:
                options = CATEGORY_OPTIONS[field]
                print(f"\nAvailable options for {field.replace('_',' ').title()}:")
                for idx, option in enumerate(options, start=1):
                    print(f"{idx}. {option}")
                
                choice = input(f"Enter {field.replace('_',' ').title()} value (choose number or type value): ").strip().lower()
                
                # If user entered a number, map to option
                if choice.isdigit():
                    choice_idx = int(choice) - 1
                    if 0 <= choice_idx < len(options):
                        user_input = options[choice_idx]
                    else:
                        print("❌ Invalid choice, defaulting to your raw input.")
                        user_input = choice
                else:
                    user_input = choice
            else:
                user_input = input(f"Enter {field.replace('_',' ').title()} value: ").strip()
            
            combined_filters[field] = user_input


        # Special case for 'id'
        if "id" in combined_filters:
            prop_id = combined_filters["id"]
            prop = next((p for p in properties_data if str(p.get("property_id")) == prop_id), None)
            if prop:
                print("\n✅ Property Found:")
                print(format_property(prop))
            else:
                print("❌ Property not found.")
            continue
        
        results = properties_data
        for field, value in combined_filters.items():
            results = filter_properties(value, field, results)
        
        if not results:
            print("❌ No properties found matching your combined search.")
        else:
            print(f"\n✅ Found {len(results)} properties matching your combined query.")
            grouped_results = defaultdict(list)
            for prop in results:
                property_type = prop.get("Room_Details", {}).get("Type", "Other/Unspecified Type")
                grouped_results[property_type].append(prop)
            
            for prop_type, props in grouped_results.items():
                print(f"\n--- 🏠 Property Type: {str(prop_type).title()} ({len(props)} results) ---")
                for prop in props:
                    print(format_property(prop))

if __name__ == "__main__":
    chatbot_response()
# Out:
# Welcome to Property Search Chatbot!
#
# Search Options:
# 1. Size (sqft)
# 2. Carpet Area (sqft)
# 3. Age of Property
# 4. Brokerage (yes/no)
# 5. Property ID (exact match)
# 6. Amenities
# 7. Furnishing Status
# 8. Security Deposit
# 9. Rent Price
# 10. Area
# 11. Zone
# 12. Bedrooms
# 13. Bathrooms
# 14. Balcony
# 15. Floor Number
# 16. Total Floors
# 17. Maintenance Charge
# 18. Recommended For
# 19. Water Supply Type
# 20. Society Type
# 21. Road Connectivity
# 22. Facilities
# 23. Nearby Amenities
# 24. Room Type (e.g., 1 BHK)
# 25. Property Type (e.g., Flat)
#
# 💡 You can combine multiple search fields using '+'.
# Example: 9+10 (Rent + Area)
# For numeric values, you can use 'above 1000', 'below 5000', 'between 1000 and 5000'.
# For facilities/amenities, separate multiple options with a comma (e.g., 'Gym,Lift').
# Type 'exit' to quit.
# Enter the number(s) of search fields to combine (e.g., 9+10) or 'exit':  1
# Enter Size value:  800
# ✅ Found 9 properties matching your combined query.
#
# --- 🏠 Property Type: Flat (5 results) ---
# ID: Property_1 | Rent: ₹10000.0 | Size: Total Area 800 .sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 1 BHK | Property Type: Flat | Bedrooms: 1 | Bathrooms: 1 | Balcony: 0
# Furnishing: Semi Furnished | Security Deposit: ₹20000.0 | Brokerage: NO
# Amenities: 1
# Facilities: Wifi
# Nearby Amenities: Hospital, School
# Floor: 2/2 | Maintenance: No | Recommended For: Family
# Water Supply: Borewell | Society: Non-Gated | Road Connectivity: 2.0 km
# Age: 5 years | Area: shatabdisquare | Zone: South Zone
# ----------------------------------------
# ID: Property_42 | Rent: ₹7000.0 | Size: Total Area 800.sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 2 BHK | Property Type: Flat | Bedrooms: 2 | Bathrooms: 2 | Balcony: 1
# Furnishing: Unfurnished | Security Deposit: ₹14000.0 | Brokerage: NO
# Amenities: 0
# Facilities: None
# Nearby Amenities: Bus Stop, Hospital, Mall, Metro Station, School
# Floor: 3/4 | Maintenance: No | Recommended For: Family and Bachelors
# Water Supply: Borewell | Society: Township | Road Connectivity: 2.0 km
# Age: 0 years | Area: Hingna | Zone: South Zone
# ----------------------------------------
# ID: Property_48 | Rent: ₹7000.0 | Size: Total Area 800.sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 2 BHK | Property Type: Flat | Bedrooms: 2 | Bathrooms: 2 | Balcony: 1
# Furnishing: Unfurnished | Security Deposit: ₹14000.0 | Brokerage: NO
# Amenities: 0
# Facilities: None
# Nearby Amenities: Bus Stop, Hospital, Metro Station, School
# Floor: 3/4 | Maintenance: No | Recommended For: Family and Bachelors
# Water Supply: Both | Society: Township | Road Connectivity: 1.0 km
# Age: 3 years | Area: Hingna | Zone: South Zone
# ----------------------------------------
# ID: Property_113 | Rent: ₹10000.0 | Size: Total Area 800.sqft  sqft | Carpet Area: Carpet Area 700.0 sqft sqft
# Rooms: 1 BHK | Property Type: Flat | Bedrooms: 1 | Bathrooms: 1 | Balcony: 1
# Furnishing: Semi Furnished | Security Deposit: ₹20000.0 | Brokerage: YES
# Amenities: 5
# Facilities: Lift, Water Supply, Kids Area, Power Backup, Parking
# Nearby Amenities: Hospital, Mall, Metro Station, School
# Floor: 1/3 | Maintenance: No | Recommended For: 0
# Water Supply: Both | Society: Township | Road Connectivity: 2.0 km
# Age: 5 years | Area: reshim bagh | Zone: East Zone
# ----------------------------------------
# ID: Property_1000 | Rent: ₹20000.0 | Size: Total Area 800.sqft  sqft | Carpet Area: Carpet Area 750.0 sqft sqft
# Rooms: 2 BHK | Property Type: Flat | Bedrooms: 2 | Bathrooms: 2 | Balcony: 0
# Furnishing: Semi Furnished | Security Deposit: ₹40000.0 | Brokerage: YES
# Amenities: 1
# Facilities: Parking
# Nearby Amenities: Airport, Metro Station
# Floor: 3/5 | Maintenance: yes | Recommended For: Anyone
# Water Supply: Borewell | Society: Gated | Road Connectivity: 2.0 km
# Age: 15 years | Area: sadar | Zone: West Zone
# ----------------------------------------
#
# --- 🏠 Property Type: 0 (1 results) ---
# ID: Property_18 | Rent: ₹10000.0 | Size: Total Area 800 .sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 0 | Property Type: 0 | Bedrooms: 2 | Bathrooms: 2 | Balcony: 0
# Furnishing: Unfurnished | Security Deposit: ₹20000.0 | Brokerage: NO
# Amenities: 0
# Facilities: None
# Nearby Amenities: Hospital, Mall, Metro Station, School
# Floor: 0/0 | Maintenance: No | Recommended For: Family
# Water Supply: Municipal | Society: Non-Gated | Road Connectivity: 2.0 km
# Age: 0 years | Area: itwari | Zone: East Zone
# ----------------------------------------
#
# --- 🏠 Property Type: Independent House (2 results) ---
# ID: Property_99 | Rent: ₹4000.0 | Size: Total Area 800.sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 1 RK | Property Type: Independent House | Bedrooms: 1 | Bathrooms: 1 | Balcony: 0
# Furnishing: Unfurnished | Security Deposit: ₹8000.0 | Brokerage: NO
# Amenities: 0
# Facilities: None
# Nearby Amenities: Hospital, Mall, Metro Station, School
# Floor: 0/0 | Maintenance: No | Recommended For: Bachelors
# Water Supply: Municipal | Society: Gated | Road Connectivity: 2.0 km
# Age: 1 years | Area: dighori | Zone: South Zone
# ----------------------------------------
# ID: Property_192 | Rent: ₹4000.0 | Size: Total Area 800.sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 1 RK | Property Type: Independent House | Bedrooms: 1 | Bathrooms: 1 | Balcony: 0
# Furnishing: Unfurnished | Security Deposit: ₹8000.0 | Brokerage: NO
# Amenities: 0
# Facilities: None
# Nearby Amenities: Hospital, Mall, Metro Station, School
# Floor: 0/0 | Maintenance: No | Recommended For: Bachelors
# Water Supply: Borewell | Society: Non-Gated | Road Connectivity: 2.0 km
# Age: 1 years | Area: dighori | Zone: South Zone
# ----------------------------------------
#
# --- 🏠 Property Type: Independent Builder Floor (1 results) ---
# ID: Property_106 | Rent: ₹11000.0 | Size: Total Area 800.sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 1 BHK | Property Type: Independent Builder Floor | Bedrooms: 1 | Bathrooms: 1 | Balcony: 1
# Furnishing: Semi Furnished | Security Deposit: ₹22000.0 | Brokerage: YES
# Amenities: 10
# Facilities: Gated Community, Gym, Lift, Pet Allowed, Water Supply, Kids Area, Garden, Fire Support, Parking
# Nearby Amenities: Atm, Hospital, Mall, Metro Station, School
# Floor: 2/4 | Maintenance: No | Recommended For: Family and Bachelors
# Water Supply: Municipal | Society: Non-Gated | Road Connectivity: 1.0 km
# Age: 1 years | Area: manish nagar | Zone: South Zone
# ----------------------------------------
# Enter the number(s) of search fields to combine (e.g., 9+10) or 'exit':  exit
# Goodbye!

# %%
import json
import re
from collections import defaultdict

# --- Load properties from JSON file ---
try:
    with open("property_data.json", "r") as f:
        properties_data = json.load(f)
except FileNotFoundError:
    print("Error: 'property_data.json' not found. Please ensure the file exists.")
    properties_data = []
except json.JSONDecodeError:
    print("Error: Could not decode 'property_data.json'. Please check its format.")
    properties_data = []

# --- Helper functions for normalization ---
def normalize_area_name(area_name):
    return str(area_name).replace(" ", "").lower().strip()

def normalize_zone_name(zone_name):
    return str(zone_name).replace(" ", "").lower().strip()

def normalize_facility_name(facility_name):
    return str(facility_name).replace(" ", "_").lower().strip()

def normalize_amenity_name(name):
    return str(name).replace(" ", "_").lower().strip()

def normalize_room_name(room_name):
    return str(room_name).replace(" ", "").lower().strip()

def normalize_property_type_name(prop_type):
    return str(prop_type).lower().strip()

def get_numeric_value(value):
    """Extract integer from strings like '800 sqft', '10 years', etc.
        Returns None if no number is found."""
    if not value:
        return None
    match = re.search(r"\d+", str(value))
    return int(match.group()) if match else None


# --- Dynamically get all unique values from the dataset ---
ALL_AREAS = sorted(
    list(set(normalize_area_name(p.get("Area", "N/A")) for p in properties_data))
)

ALL_ZONES = sorted(
    list(set(normalize_zone_name(p.get("Zone", "N/A")) for p in properties_data))
)

ALL_FACILITIES = []
for p in properties_data:
    if "Facilities" in p and isinstance(p["Facilities"], dict):
        ALL_FACILITIES = sorted(list(p["Facilities"].keys()))
        break

ALL_NEARBY_AMENITIES = []
for p in properties_data:
    if "Nearby_Amenities" in p and isinstance(p["Nearby_Amenities"], dict):
        ALL_NEARBY_AMENITIES = sorted(list(p["Nearby_Amenities"].keys()))
        break

ALL_ROOM_TYPES = sorted(
    list(set(normalize_room_name(p.get("Room_Details", {}).get("Rooms", "N/A"))
             for p in properties_data if p.get("Room_Details", {}).get("Rooms")))
)

ALL_PROPERTY_TYPES = sorted(
    list(set(normalize_property_type_name(p.get("Room_Details", {}).get("Type", "N/A"))
             for p in properties_data if p.get("Room_Details", {}).get("Type")))
)



# --- Filtering logic ---
def filter_properties(user_input, field, data):
    filtered_properties = []

    # Map search field to the actual key in properties_data
    data_field_map = {
        "size": "Size_In_Sqft", "carpet": "Carpet_Area_Sqft", "age": "Property_Age", "brokerage": "Brokerage",
        "furnishing": "Furnishing_Status", "amenities": "Number_Of_Amenities", "security": "Security_Deposite", "rent": "Rent_Price",
        "area": "Area", "zone": "Zone", "bedrooms": "Bedrooms", "bathrooms": "Bathrooms", "balcony": "Balcony",
        "floor_no": "Floor_No", "total_floors": "Total_floors_In_Building", "maintenance": "Maintenance_Charge",
        "recommended_for": "Recommended_For", "water_supply": "Water_Supply_Type", "society_type": "Society_Type",
        "road_connectivity": "Road_Connectivity", "facilities": "Facilities", "nearby_amenities": "Nearby_Amenities",
        "room_type": "Room_Details", "property_type": "Room_Details", "id": "property_id"
    }
    data_field = data_field_map.get(field)
    if not data_field:
        return []

    # --- String fields ---
    normalized_user_input = user_input.lower().strip()
    if field in ["brokerage", "furnishing", "maintenance", "recommended_for", "water_supply", "society_type"]:
        filtered_properties = [p for p in data if str(p.get(data_field, "N/A")).lower() == normalized_user_input]

    elif field == "facilities":
        user_facilities = [normalize_facility_name(f) for f in user_input.split(',')]
        filtered_properties = [
            p for p in data
            if all(
                any(normalize_facility_name(k) == fac and v == 1
                    for k, v in p.get("Facilities", {}).items())
                for fac in user_facilities
            )
        ]


    elif field == "nearby_amenities":
        user_facilities = [normalize_facility_name(f) for f in user_input.split(',')]
        filtered_properties = [
            p for p in data
            if all(
                any(normalize_facility_name(k) == fac and v == 1
                    for k, v in p.get("Nearby_Amenities", {}).items())
                for fac in user_facilities
            )
        ]

    elif field == "room_type":
        filtered_properties = [p for p in data if normalize_room_name(p.get("Room_Details", {}).get("Rooms", "")) == normalized_user_input]

    elif field == "property_type":
        filtered_properties = [p for p in data if normalize_property_type_name(p.get("Room_Details", {}).get("Type", "")) == normalized_user_input]

    elif field == "area":
        filtered_properties = [p for p in data if normalize_area_name(p.get("Area", "N/A")) == normalize_area_name(user_input)]

    elif field == "zone":
        filtered_properties = [p for p in data if normalize_zone_name(p.get("Zone", "N/A")) == normalize_zone_name(user_input)]

    elif field == "id":
        filtered_properties = [p for p in data if str(p.get(data_field)) == user_input.strip()]

    else:
        try:
            val = get_numeric_value(user_input)
    
            if user_input.startswith("below"):
                filtered_properties = [
                    p for p in data
                    if get_numeric_value(p.get(data_field)) is not None
                    and get_numeric_value(p.get(data_field)) < val
                ]
            elif user_input.startswith("above"):
                filtered_properties = [
                    p for p in data
                    if get_numeric_value(p.get(data_field)) is not None
                    and get_numeric_value(p.get(data_field)) > val
                ]
            elif user_input.startswith("between"):
                nums = re.findall(r"\d+", user_input)
                if len(nums) == 2:
                    low, high = int(nums[0]), int(nums[1])
                    filtered_properties = [
                        p for p in data
                        if get_numeric_value(p.get(data_field)) is not None
                        and low <= get_numeric_value(p.get(data_field)) <= high
                    ]
            else:
                filtered_properties = [
                    p for p in data
                    if get_numeric_value(p.get(data_field)) == val
                ]
    
        except Exception:
            return []

    return filtered_properties

# --- Format results ---
def format_property(prop):
    property_id = prop.get('property_id', 'N/A')
    rent_price = prop.get('Rent_Price', 'N/A')
    size = prop.get('Size_In_Sqft', 'Unknown')
    carpet_area = prop.get('Carpet_Area_Sqft', 'Unknown')
    security_deposit = prop.get('Security_Deposite', 'N/A')
    brokerage = prop.get('Brokerage', 'N/A')
    furnishing_status = prop.get('Furnishing_Status', 'N/A')
    amenities = prop.get('Number_Of_Amenities',0)
    age = prop.get('Property_Age', 'Unknown')
    area = prop.get('Area', 'N/A')
    zone = prop.get('Zone', 'N/A')
    bedrooms = prop.get('Bedrooms', 'N/A')
    bathrooms = prop.get('Bathrooms', 'N/A')
    balcony = prop.get('Balcony', 'N/A')
    floor_no = prop.get('Floor_No', 'N/A')
    total_floors = prop.get('Total_floors_In_Building', 'N/A')
    maintenance = prop.get('Maintenance_Charge', 'N/A')
    recommended_for = prop.get('Recommended_For', 'N/A')
    water_supply = prop.get('Water_Supply_Type', 'N/A')
    society_type = prop.get('Society_Type', 'N/A')
    road_connectivity = prop.get('Road_Connectivity', 'N/A')
    facilities_list = [k.replace("_", " ").title() for k, v in prop.get("Facilities", {}).items() if v == 1]
    facilities = ', '.join(facilities_list) if facilities_list else 'None'
    nearby_amenities_list = [k.replace("_", " ").title() for k, v in prop.get("Nearby_Amenities", {}).items() if v == 1]
    nearby_amenities = ', '.join(nearby_amenities_list) if nearby_amenities_list else 'None'
    rooms = prop.get("Room_Details", {}).get("Rooms", "N/A")
    property_type = prop.get("Room_Details", {}).get("Type", "N/A")

    return (
        f"ID: {property_id} | Rent: ₹{rent_price} | Size: {size} sqft | Carpet Area: {carpet_area} sqft\n"
        f"Rooms: {rooms} | Property Type: {property_type} | Bedrooms: {bedrooms} | Bathrooms: {bathrooms} | Balcony: {balcony}\n"
        f"Furnishing: {furnishing_status} | Security Deposit: ₹{security_deposit} | Brokerage: {brokerage}\n"
        f"Amenities: {amenities}\n"
        f"Facilities: {facilities}\n"
        f"Nearby Amenities: {nearby_amenities}\n"
        f"Floor: {floor_no}/{total_floors} | Maintenance: {maintenance} | Recommended For: {recommended_for}\n"
        f"Water Supply: {water_supply} | Society: {society_type} | Road Connectivity: {road_connectivity} km\n"
        f"Age: {age} years | Area: {area} | Zone: {zone}\n"
        f"----------------------------------------"
    )

# --- The existing property search chatbot logic, now the 'inner' chatbot ---
def property_search_chatbot():
    print("Welcome to Property Search Chatbot!")
    print("\nSearch Options:")
    print(
        "1. Size (sqft)\n2. Carpet Area (sqft)\n3. Age of Property\n4. Brokerage (yes/no)\n5. Property ID (exact match)\n"
        "6. Amenities\n7. Furnishing Status\n8. Security Deposit\n9. Rent Price\n10. Area\n11. Zone\n"
        "12. Bedrooms\n13. Bathrooms\n14. Balcony\n15. Floor Number\n16. Total Floors\n17. Maintenance Charge\n"
        "18. Recommended For\n19. Water Supply Type\n20. Society Type\n21. Road Connectivity\n22. Facilities\n"
        "23. Nearby Amenities\n24. Room Type (e.g., 1 BHK)\n25. Property Type (e.g., Flat)\n"
    )
    print("💡 You can combine multiple search fields using '+'.")
    print("Example: 9+10 (Rent + Area)")
    print("For numeric values, you can use 'above 1000', 'below 5000', 'between 1000 and 5000'.")
    print("For facilities/amenities, separate multiple options with a comma (e.g., 'Gym,Lift').")
    print("Type 'back' to return to the main menu.")

    CATEGORY_OPTIONS = {
    "brokerage": sorted(list(set(str(p.get("Brokerage", "N/A")).lower() for p in properties_data))),
    "furnishing": sorted(list(set(str(p.get("Furnishing_Status", "N/A")).lower() for p in properties_data))),
    "maintenance": sorted(list(set(str(p.get("Maintenance_Charge", "N/A")).lower() for p in properties_data))),
    "recommended_for": sorted(list(set(str(p.get("Recommended_For", "N/A")).lower() for p in properties_data))),
    "water_supply": sorted(list(set(str(p.get("Water_Supply_Type", "N/A")).lower() for p in properties_data))),
    "society_type": sorted(list(set(str(p.get("Society_Type", "N/A")).lower() for p in properties_data))),
    "area": ALL_AREAS,
    "zone": ALL_ZONES,
    "room_type": ALL_ROOM_TYPES,
    "property_type": ALL_PROPERTY_TYPES,
    "facilities": ALL_FACILITIES,
    "nearby_amenities": ALL_NEARBY_AMENITIES
    }


    search_map = {
        "1": "size", "2": "carpet", "3": "age", "4": "brokerage", "5": "id", "6": "amenities", "7": "furnishing",
        "8": "security", "9": "rent", "10": "area", "11": "zone", "12": "bedrooms", "13": "bathrooms",
        "14": "balcony", "15": "floor_no", "16": "total_floors", "17": "maintenance", "18": "recommended_for",
        "19": "water_supply", "20": "society_type", "21": "road_connectivity", "22": "facilities", "23": "nearby_amenities",
        "24": "room_type", "25": "property_type"
    }

    while True:
        field_numbers = input("\nEnter the number(s) of search fields to combine (e.g., 9+10) or 'back': ").strip().lower()
        if field_numbers == "back":
            print("Returning to main menu.")
            break

        selected_fields = []
        is_valid_input = True
        for num in field_numbers.split('+'):
            num = num.strip()
            if num in search_map:
                selected_fields.append(search_map[num])
            else:
                print(f"❌ Invalid field number: '{num}'. Please use a valid number from the list.")
                is_valid_input = False
                break
        
        if not is_valid_input:
            continue

        combined_filters = {}
        for field in selected_fields:
            if field in CATEGORY_OPTIONS and CATEGORY_OPTIONS[field]:
                options = CATEGORY_OPTIONS[field]
                print(f"\nAvailable options for {field.replace('_',' ').title()}:")
                for idx, option in enumerate(options, start=1):
                    print(f"{idx}. {option}")
                
                choice = input(f"Enter {field.replace('_',' ').title()} value (choose number or type value): ").strip().lower()
                
                # If user entered a number, map to option
                if choice.isdigit():
                    choice_idx = int(choice) - 1
                    if 0 <= choice_idx < len(options):
                        user_input = options[choice_idx]
                    else:
                        print("❌ Invalid choice, defaulting to your raw input.")
                        user_input = choice
                else:
                    user_input = choice
            else:
                user_input = input(f"Enter {field.replace('_',' ').title()} value: ").strip()
            
            combined_filters[field] = user_input


        # Special case for 'id'
        if "id" in combined_filters:
            prop_id = combined_filters["id"]
            prop = next((p for p in properties_data if str(p.get("property_id")) == prop_id), None)
            if prop:
                print("\n✅ Property Found:")
                print(format_property(prop))
            else:
                print("❌ Property not found.")
            continue
        
        results = properties_data
        for field, value in combined_filters.items():
            results = filter_properties(value, field, results)
        
        if not results:
            print("❌ No properties found matching your combined search.")
        else:
            print(f"\n✅ Found {len(results)} properties matching your combined query.")
            grouped_results = defaultdict(list)
            for prop in results:
                property_type = prop.get("Room_Details", {}).get("Type", "Other/Unspecified Type")
                grouped_results[property_type].append(prop)
            
            for prop_type, props in grouped_results.items():
                print(f"\n--- 🏠 Property Type: {str(prop_type).title()} ({len(props)} results) ---")
                for prop in props:
                    print(format_property(prop))

# --- Main 'outer' chatbot logic ---
def main_chatbot():
    print("Welcome to the Main Chatbot!")
    print("I can help you with a few things. Here are my current commands:")
    print("1. 'search properties' - Start the property search tool.")
    print("2. 'exit' - End the conversation.")

    while True:
        user_input = input("\nWhat can I help you with? ").strip().lower()

        if user_input == 'search properties':
            # This is where the inner chatbot is called
            property_search_chatbot()
        elif user_input == 'exit':
            print("Goodbye! Thank you for using the chatbot.")
            break
        else:
            print("I'm sorry, I don't understand that command. Please type 'search properties' or 'exit'.")

if __name__ == "__main__":
    main_chatbot()
# Out:
# Welcome to the Main Chatbot!
# I can help you with a few things. Here are my current commands:
# 1. 'search properties' - Start the property search tool.
# 2. 'exit' - End the conversation.
# What can I help you with?  i want 800 sqqft total area
# I'm sorry, I don't understand that command. Please type 'search properties' or 'exit'.
# What can I help you with?  1
# I'm sorry, I don't understand that command. Please type 'search properties' or 'exit'.
# What can I help you with?  1
# I'm sorry, I don't understand that command. Please type 'search properties' or 'exit'.
# What can I help you with?  search properties
# Welcome to Property Search Chatbot!
#
# Search Options:
# 1. Size (sqft)
# 2. Carpet Area (sqft)
# 3. Age of Property
# 4. Brokerage (yes/no)
# 5. Property ID (exact match)
# 6. Amenities
# 7. Furnishing Status
# 8. Security Deposit
# 9. Rent Price
# 10. Area
# 11. Zone
# 12. Bedrooms
# 13. Bathrooms
# 14. Balcony
# 15. Floor Number
# 16. Total Floors
# 17. Maintenance Charge
# 18. Recommended For
# 19. Water Supply Type
# 20. Society Type
# 21. Road Connectivity
# 22. Facilities
# 23. Nearby Amenities
# 24. Room Type (e.g., 1 BHK)
# 25. Property Type (e.g., Flat)
#
# 💡 You can combine multiple search fields using '+'.
# Example: 9+10 (Rent + Area)
# For numeric values, you can use 'above 1000', 'below 5000', 'between 1000 and 5000'.
# For facilities/amenities, separate multiple options with a comma (e.g., 'Gym,Lift').
# Type 'back' to return to the main menu.
# Enter the number(s) of search fields to combine (e.g., 9+10) or 'back':  size 800
# ❌ Invalid field number: 'size 800'. Please use a valid number from the list.
# Enter the number(s) of search fields to combine (e.g., 9+10) or 'back':  exit
# ❌ Invalid field number: 'exit'. Please use a valid number from the list.
# Enter the number(s) of search fields to combine (e.g., 9+10) or 'back':  exit
# ❌ Invalid field number: 'exit'. Please use a valid number from the list.
# Enter the number(s) of search fields to combine (e.g., 9+10) or 'back':  back
# Returning to main menu.
# What can I help you with?  exit
# Goodbye! Thank you for using the chatbot.

# %%
import json
import re
from collections import defaultdict

# --- Load properties from JSON file ---
try:
    with open("property_data.json", "r") as f:
        properties_data = json.load(f)
except FileNotFoundError:
    print("Error: 'property_data.json' not found. Please ensure the file exists.")
    properties_data = []
except json.JSONDecodeError:
    print("Error: Could not decode 'property_data.json'. Please check its format.")
    properties_data = []

# --- Helper functions for normalization ---
def normalize_area_name(area_name):
    return str(area_name).replace(" ", "").lower().strip()

def normalize_zone_name(zone_name):
    return str(zone_name).replace(" ", "").lower().strip()

def normalize_facility_name(facility_name):
    return str(facility_name).replace(" ", "_").lower().strip()

def normalize_amenity_name(name):
    return str(name).replace(" ", "_").lower().strip()

def normalize_room_name(room_name):
    return str(room_name).replace(" ", "").lower().strip()

def normalize_property_type_name(prop_type):
    return str(prop_type).lower().strip()

def get_numeric_value(value):
    """Extract integer from strings, supporting both digits and spelled-out numbers.
        Returns None if no number is found."""
    if not value:
        return None
    
    # Dictionary for number words
    num_words = {
        'one': 1, 'two': 2, 'three': 3, 'four': 4, 'five': 5,
        'six': 6, 'seven': 7, 'eight': 8, 'nine': 9, 'ten': 10,
        'eleven': 11, 'twelve': 12, 'thirteen': 13, 'fourteen': 14,
        'fifteen': 15, 'sixteen': 16, 'seventeen': 17, 'eighteen': 18,
        'nineteen': 19, 'twenty': 20, 'thirty': 30, 'forty': 40,
        'fifty': 50, 'sixty': 60, 'seventy': 70, 'eighty': 80,
        'ninety': 90, 'hundred': 100, 'thousand': 1000, 'lakh': 100000,
        'million': 1000000, 'crore': 10000000
    }

    # Normalize the input string
    normalized_value = str(value).lower().strip().replace('-', ' ')
    
    # Check for number words first
    total_value = 0
    current_number = 0
    words = normalized_value.split()
    
    for word in words:
        if word in num_words:
            if num_words[word] >= 100:
                total_value += current_number * num_words[word]
                current_number = 0
            else:
                current_number += num_words[word]
    total_value += current_number

    # If number words were found, return the calculated value
    if total_value > 0:
        return total_value
    
    # If no number words, search for digits
    match = re.search(r"\d+", normalized_value)
    return int(match.group()) if match else None


# --- Dynamically get all unique values from the dataset ---
ALL_AREAS = sorted(
    list(set(normalize_area_name(p.get("Area", "N/A")) for p in properties_data))
)

ALL_ZONES = sorted(
    list(set(normalize_zone_name(p.get("Zone", "N/A")) for p in properties_data))
)

ALL_FACILITIES = []
for p in properties_data:
    if "Facilities" in p and isinstance(p["Facilities"], dict):
        ALL_FACILITIES = sorted(list(p["Facilities"].keys()))
        break

ALL_NEARBY_AMENITIES = []
for p in properties_data:
    if "Nearby_Amenities" in p and isinstance(p["Nearby_Amenities"], dict):
        ALL_NEARBY_AMENITIES = sorted(list(p["Nearby_Amenities"].keys()))
        break

ALL_ROOM_TYPES = sorted(
    list(set(normalize_room_name(p.get("Room_Details", {}).get("Rooms", "N/A"))
             for p in properties_data if p.get("Room_Details", {}).get("Rooms")))
)

ALL_PROPERTY_TYPES = sorted(
    list(set(normalize_property_type_name(p.get("Room_Details", {}).get("Type", "N/A"))
             for p in properties_data if p.get("Room_Details", {}).get("Type")))
)



# --- Filtering logic ---
def filter_properties(user_input, field, data):
    filtered_properties = []

    # Map search field to the actual key in properties_data
    data_field_map = {
        "size": "Size_In_Sqft", "carpet": "Carpet_Area_Sqft", "age": "Property_Age", "brokerage": "Brokerage",
        "furnishing": "Furnishing_Status", "amenities": "Number_Of_Amenities", "security": "Security_Deposite", "rent": "Rent_Price",
        "area": "Area", "zone": "Zone", "bedrooms": "Bedrooms", "bathrooms": "Bathrooms", "balcony": "Balcony",
        "floor_no": "Floor_No", "total_floors": "Total_floors_In_Building", "maintenance": "Maintenance_Charge",
        "recommended_for": "Recommended_For", "water_supply": "Water_Supply_Type", "society_type": "Society_Type",
        "road_connectivity": "Road_Connectivity", "facilities": "Facilities", "nearby_amenities": "Nearby_Amenities",
        "room_type": "Room_Details", "property_type": "Room_Details", "id": "property_id"
    }
    data_field = data_field_map.get(field)
    if not data_field:
        return []

    # --- String fields ---
    normalized_user_input = user_input.lower().strip()
    if field in ["brokerage", "furnishing", "maintenance", "recommended_for", "water_supply", "society_type"]:
        filtered_properties = [p for p in data if str(p.get(data_field, "N/A")).lower() == normalized_user_input]

    elif field == "facilities":
        user_facilities = [normalize_facility_name(f) for f in user_input.split(',')]
        filtered_properties = [
            p for p in data
            if all(
                any(normalize_facility_name(k) == fac and v == 1
                    for k, v in p.get("Facilities", {}).items())
                for fac in user_facilities
            )
        ]


    elif field == "nearby_amenities":
        user_facilities = [normalize_facility_name(f) for f in user_input.split(',')]
        filtered_properties = [
            p for p in data
            if all(
                any(normalize_facility_name(k) == fac and v == 1
                    for k, v in p.get("Nearby_Amenities", {}).items())
                for fac in user_facilities
            )
        ]

    elif field == "room_type":
        filtered_properties = [p for p in data if normalize_room_name(p.get("Room_Details", {}).get("Rooms", "")) == normalized_user_input]

    elif field == "property_type":
        filtered_properties = [p for p in data if normalize_property_type_name(p.get("Room_Details", {}).get("Type", "")) == normalized_user_input]

    elif field == "area":
        filtered_properties = [p for p in data if normalize_area_name(p.get("Area", "N/A")) == normalize_area_name(user_input)]

    elif field == "zone":
        filtered_properties = [p for p in data if normalize_zone_name(p.get("Zone", "N/A")) == normalize_zone_name(user_input)]

    elif field == "id":
        filtered_properties = [p for p in data if str(p.get(data_field)) == user_input.strip()]

    else:
        try:
            val = get_numeric_value(user_input)
    
            if user_input.startswith("below"):
                filtered_properties = [
                    p for p in data
                    if get_numeric_value(p.get(data_field)) is not None
                    and get_numeric_value(p.get(data_field)) < val
                ]
            elif user_input.startswith("above"):
                filtered_properties = [
                    p for p in data
                    if get_numeric_value(p.get(data_field)) is not None
                    and get_numeric_value(p.get(data_field)) > val
                ]
            elif user_input.startswith("between"):
                nums = re.findall(r"\d+", user_input)
                if len(nums) == 2:
                    low, high = int(nums[0]), int(nums[1])
                    filtered_properties = [
                        p for p in data
                        if get_numeric_value(p.get(data_field)) is not None
                        and low <= get_numeric_value(p.get(data_field)) <= high
                    ]
            else:
                filtered_properties = [
                    p for p in data
                    if get_numeric_value(p.get(data_field)) == val
                ]
    
        except Exception:
            return []

    return filtered_properties

# --- Format results ---
def format_property(prop):
    property_id = prop.get('property_id', 'N/A')
    rent_price = prop.get('Rent_Price', 'N/A')
    size = prop.get('Size_In_Sqft', 'Unknown')
    carpet_area = prop.get('Carpet_Area_Sqft', 'Unknown')
    security_deposit = prop.get('Security_Deposite', 'N/A')
    brokerage = prop.get('Brokerage', 'N/A')
    furnishing_status = prop.get('Furnishing_Status', 'N/A')
    amenities = prop.get('Number_Of_Amenities',0)
    age = prop.get('Property_Age', 'Unknown')
    area = prop.get('Area', 'N/A')
    zone = prop.get('Zone', 'N/A')
    bedrooms = prop.get('Bedrooms', 'N/A')
    bathrooms = prop.get('Bathrooms', 'N/A')
    balcony = prop.get('Balcony', 'N/A')
    floor_no = prop.get('Floor_No', 'N/A')
    total_floors = prop.get('Total_floors_In_Building', 'N/A')
    maintenance = prop.get('Maintenance_Charge', 'N/A')
    recommended_for = prop.get('Recommended_For', 'N/A')
    water_supply = prop.get('Water_Supply_Type', 'N/A')
    society_type = prop.get('Society_Type', 'N/A')
    road_connectivity = prop.get('Road_Connectivity', 'N/A')
    facilities_list = [k.replace("_", " ").title() for k, v in prop.get("Facilities", {}).items() if v == 1]
    facilities = ', '.join(facilities_list) if facilities_list else 'None'
    nearby_amenities_list = [k.replace("_", " ").title() for k, v in prop.get("Nearby_Amenities", {}).items() if v == 1]
    nearby_amenities = ', '.join(nearby_amenities_list) if nearby_amenities_list else 'None'
    rooms = prop.get("Room_Details", {}).get("Rooms", "N/A")
    property_type = prop.get("Room_Details", {}).get("Type", "N/A")

    return (
        f"ID: {property_id} | Rent: ₹{rent_price} | Size: {size} sqft | Carpet Area: {carpet_area} sqft\n"
        f"Rooms: {rooms} | Property Type: {property_type} | Bedrooms: {bedrooms} | Bathrooms: {bathrooms} | Balcony: {balcony}\n"
        f"Furnishing: {furnishing_status} | Security Deposit: ₹{security_deposit} | Brokerage: {brokerage}\n"
        f"Amenities: {amenities}\n"
        f"Facilities: {facilities}\n"
        f"Nearby Amenities: {nearby_amenities}\n"
        f"Floor: {floor_no}/{total_floors} | Maintenance: {maintenance} | Recommended For: {recommended_for}\n"
        f"Water Supply: {water_supply} | Society: {society_type} | Road Connectivity: {road_connectivity} km\n"
        f"Age: {age} years | Area: {area} | Zone: {zone}\n"
        f"----------------------------------------"
    )

# --- The existing property search chatbot logic, now the 'inner' chatbot ---
def property_search_chatbot():
    print("Welcome to Property Search Chatbot!")
    print("\nSearch Options:")
    print(
        "1. Size (sqft)\n2. Carpet Area (sqft)\n3. Age of Property\n4. Brokerage (yes/no)\n5. Property ID (exact match)\n"
        "6. Amenities\n7. Furnishing Status\n8. Security Deposit\n9. Rent Price\n10. Area\n11. Zone\n"
        "12. Bedrooms\n13. Bathrooms\n14. Balcony\n15. Floor Number\n16. Total Floors\n17. Maintenance Charge\n"
        "18. Recommended For\n19. Water Supply Type\n20. Society Type\n21. Road Connectivity\n22. Facilities\n"
        "23. Nearby Amenities\n24. Room Type (e.g., 1 BHK)\n25. Property Type (e.g., Flat)\n"
    )
    print("💡 You can combine multiple search fields using '+'.")
    print("Example: 9+10 (Rent + Area)")
    print("For numeric values, you can use 'above 1000' or 'above one thousand', 'below 5000', 'between 1000 and 5000'.")
    print("For facilities/amenities, separate multiple options with a comma (e.g., 'Gym,Lift').")
    print("Type 'back' to return to the main menu.")

    CATEGORY_OPTIONS = {
    "brokerage": sorted(list(set(str(p.get("Brokerage", "N/A")).lower() for p in properties_data))),
    "furnishing": sorted(list(set(str(p.get("Furnishing_Status", "N/A")).lower() for p in properties_data))),
    "maintenance": sorted(list(set(str(p.get("Maintenance_Charge", "N/A")).lower() for p in properties_data))),
    "recommended_for": sorted(list(set(str(p.get("Recommended_For", "N/A")).lower() for p in properties_data))),
    "water_supply": sorted(list(set(str(p.get("Water_Supply_Type", "N/A")).lower() for p in properties_data))),
    "society_type": sorted(list(set(str(p.get("Society_Type", "N/A")).lower() for p in properties_data))),
    "area": ALL_AREAS,
    "zone": ALL_ZONES,
    "room_type": ALL_ROOM_TYPES,
    "property_type": ALL_PROPERTY_TYPES,
    "facilities": ALL_FACILITIES,
    "nearby_amenities": ALL_NEARBY_AMENITIES
    }


    search_map = {
        "1": "size", "2": "carpet", "3": "age", "4": "brokerage", "5": "id", "6": "amenities", "7": "furnishing",
        "8": "security", "9": "rent", "10": "area", "11": "zone", "12": "bedrooms", "13": "bathrooms",
        "14": "balcony", "15": "floor_no", "16": "total_floors", "17": "maintenance", "18": "recommended_for",
        "19": "water_supply", "20": "society_type", "21": "road_connectivity", "22": "facilities", "23": "nearby_amenities",
        "24": "room_type", "25": "property_type"
    }

    while True:
        field_numbers = input("\nEnter the number(s) of search fields to combine (e.g., 9+10) or 'back': ").strip().lower()
        if field_numbers == "back":
            print("Returning to main menu.")
            break

        selected_fields = []
        is_valid_input = True
        for num in field_numbers.split('+'):
            num = num.strip()
            if num in search_map:
                selected_fields.append(search_map[num])
            else:
                print(f"❌ Invalid field number: '{num}'. Please use a valid number from the list.")
                is_valid_input = False
                break
        
        if not is_valid_input:
            continue

        combined_filters = {}
        for field in selected_fields:
            if field in CATEGORY_OPTIONS and CATEGORY_OPTIONS[field]:
                options = CATEGORY_OPTIONS[field]
                print(f"\nAvailable options for {field.replace('_',' ').title()}:")
                for idx, option in enumerate(options, start=1):
                    print(f"{idx}. {option}")
                
                choice = input(f"Enter {field.replace('_',' ').title()} value (choose number or type value): ").strip().lower()
                
                # If user entered a number, map to option
                if choice.isdigit():
                    choice_idx = int(choice) - 1
                    if 0 <= choice_idx < len(options):
                        user_input = options[choice_idx]
                    else:
                        print("❌ Invalid choice, defaulting to your raw input.")
                        user_input = choice
                else:
                    user_input = choice
            else:
                user_input = input(f"Enter {field.replace('_',' ').title()} value: ").strip()
            
            combined_filters[field] = user_input


        # Special case for 'id'
        if "id" in combined_filters:
            prop_id = combined_filters["id"]
            prop = next((p for p in properties_data if str(p.get("property_id")) == prop_id), None)
            if prop:
                print("\n✅ Property Found:")
                print(format_property(prop))
            else:
                print("❌ Property not found.")
            continue
        
        results = properties_data
        for field, value in combined_filters.items():
            results = filter_properties(value, field, results)
        
        if not results:
            print("❌ No properties found matching your combined search.")
        else:
            print(f"\n✅ Found {len(results)} properties matching your combined query.")
            grouped_results = defaultdict(list)
            for prop in results:
                property_type = prop.get("Room_Details", {}).get("Type", "Other/Unspecified Type")
                grouped_results[property_type].append(prop)
            
            for prop_type, props in grouped_results.items():
                print(f"\n--- 🏠 Property Type: {str(prop_type).title()} ({len(props)} results) ---")
                for prop in props:
                    print(format_property(prop))

# --- Main 'outer' chatbot logic ---
def main_chatbot():
    print("Welcome to the Main Chatbot!")
    print("I can help you with a few things. Here are my current commands:")
    print("1. 'search properties' - Start the property search tool.")
    print("2. 'exit' - End the conversation.")

    while True:
        user_input = input("\nWhat can I help you with? ").strip().lower()

        if user_input == 'search properties':
            # This is where the inner chatbot is called
            property_search_chatbot()
        elif user_input == 'exit':
            print("Goodbye! Thank you for using the chatbot.")
            break
        else:
            print("I'm sorry, I don't understand that command. Please type 'search properties' or 'exit'.")

if __name__ == "__main__":
    main_chatbot()
# Out:
# Welcome to the Main Chatbot!
# I can help you with a few things. Here are my current commands:
# 1. 'search properties' - Start the property search tool.
# 2. 'exit' - End the conversation.
# What can I help you with?  search properties
# Welcome to Property Search Chatbot!
#
# Search Options:
# 1. Size (sqft)
# 2. Carpet Area (sqft)
# 3. Age of Property
# 4. Brokerage (yes/no)
# 5. Property ID (exact match)
# 6. Amenities
# 7. Furnishing Status
# 8. Security Deposit
# 9. Rent Price
# 10. Area
# 11. Zone
# 12. Bedrooms
# 13. Bathrooms
# 14. Balcony
# 15. Floor Number
# 16. Total Floors
# 17. Maintenance Charge
# 18. Recommended For
# 19. Water Supply Type
# 20. Society Type
# 21. Road Connectivity
# 22. Facilities
# 23. Nearby Amenities
# 24. Room Type (e.g., 1 BHK)
# 25. Property Type (e.g., Flat)
#
# 💡 You can combine multiple search fields using '+'.
# Example: 9+10 (Rent + Area)
# For numeric values, you can use 'above 1000' or 'above one thousand', 'below 5000', 'between 1000 and 5000'.
# For facilities/amenities, separate multiple options with a comma (e.g., 'Gym,Lift').
# Type 'back' to return to the main menu.
# Enter the number(s) of search fields to combine (e.g., 9+10) or 'back':  size 800
# ❌ Invalid field number: 'size 800'. Please use a valid number from the list.
# Enter the number(s) of search fields to combine (e.g., 9+10) or 'back':  back
# Returning to main menu.
# What can I help you with?  exit
# Goodbye! Thank you for using the chatbot.

# %%
import json
import re
from collections import defaultdict

# --- Load properties from JSON file ---
try:
    with open("property_data.json", "r") as f:
        properties_data = json.load(f)
except FileNotFoundError:
    print("Error: 'property_data.json' not found. Please ensure the file exists.")
    properties_data = []
except json.JSONDecodeError:
    print("Error: Could not decode 'property_data.json'. Please check its format.")
    properties_data = []

# --- Helper functions for normalization ---
def normalize_area_name(area_name):
    return str(area_name).replace(" ", "").lower().strip()

def normalize_zone_name(zone_name):
    return str(zone_name).replace(" ", "").lower().strip()

def normalize_facility_name(facility_name):
    return str(facility_name).replace(" ", "_").lower().strip()

def normalize_amenity_name(name):
    return str(name).replace(" ", "_").lower().strip()

def normalize_room_name(room_name):
    return str(room_name).replace(" ", "").lower().strip()

def normalize_property_type_name(prop_type):
    return str(prop_type).lower().strip()

def get_numeric_value(value):
    """Extract integer from strings, supporting both digits and spelled-out numbers.
        Returns None if no number is found."""
    if not value:
        return None
    
    # Dictionary for number words
    num_words = {
        'one': 1, 'two': 2, 'three': 3, 'four': 4, 'five': 5,
        'six': 6, 'seven': 7, 'eight': 8, 'nine': 9, 'ten': 10,
        'eleven': 11, 'twelve': 12, 'thirteen': 13, 'fourteen': 14,
        'fifteen': 15, 'sixteen': 16, 'seventeen': 17, 'eighteen': 18,
        'nineteen': 19, 'twenty': 20, 'thirty': 30, 'forty': 40,
        'fifty': 50, 'sixty': 60, 'seventy': 70, 'eighty': 80,
        'ninety': 90, 'hundred': 100, 'thousand': 1000, 'lakh': 100000,
        'million': 1000000, 'crore': 10000000
    }

    # Normalize the input string
    normalized_value = str(value).lower().strip().replace('-', ' ')
    
    # Check for number words first
    total_value = 0
    current_number = 0
    words = normalized_value.split()
    
    for word in words:
        if word in num_words:
            if num_words[word] >= 100:
                total_value += current_number * num_words[word]
                current_number = 0
            else:
                current_number += num_words[word]
    total_value += current_number

    # If number words were found, return the calculated value
    if total_value > 0:
        return total_value
    
    # If no number words, search for digits
    match = re.search(r"\d+", normalized_value)
    return int(match.group()) if match else None


# --- Dynamically get all unique values from the dataset ---
ALL_AREAS = sorted(
    list(set(normalize_area_name(p.get("Area", "N/A")) for p in properties_data))
)

ALL_ZONES = sorted(
    list(set(normalize_zone_name(p.get("Zone", "N/A")) for p in properties_data))
)

ALL_FACILITIES = []
for p in properties_data:
    if "Facilities" in p and isinstance(p["Facilities"], dict):
        ALL_FACILITIES = sorted(list(p["Facilities"].keys()))
        break

ALL_NEARBY_AMENITIES = []
for p in properties_data:
    if "Nearby_Amenities" in p and isinstance(p["Nearby_Amenities"], dict):
        ALL_NEARBY_AMENITIES = sorted(list(p["Nearby_Amenities"].keys()))
        break

ALL_ROOM_TYPES = sorted(
    list(set(normalize_room_name(p.get("Room_Details", {}).get("Rooms", "N/A"))
             for p in properties_data if p.get("Room_Details", {}).get("Rooms")))
)

ALL_PROPERTY_TYPES = sorted(
    list(set(normalize_property_type_name(p.get("Room_Details", {}).get("Type", "N/A"))
             for p in properties_data if p.get("Room_Details", {}).get("Type")))
)



# --- Filtering logic ---
def filter_properties(user_input, field, data):
    filtered_properties = []

    # Map search field to the actual key in properties_data
    data_field_map = {
        "size": "Size_In_Sqft", "carpet": "Carpet_Area_Sqft", "age": "Property_Age", "brokerage": "Brokerage",
        "furnishing": "Furnishing_Status", "amenities": "Number_Of_Amenities", "security": "Security_Deposite", "rent": "Rent_Price",
        "area": "Area", "zone": "Zone", "bedrooms": "Bedrooms", "bathrooms": "Bathrooms", "balcony": "Balcony",
        "floor_no": "Floor_No", "total_floors": "Total_floors_In_Building", "maintenance": "Maintenance_Charge",
        "recommended_for": "Recommended_For", "water_supply": "Water_Supply_Type", "society_type": "Society_Type",
        "road_connectivity": "Road_Connectivity", "facilities": "Facilities", "nearby_amenities": "Nearby_Amenities",
        "room_type": "Room_Details", "property_type": "Room_Details", "id": "property_id"
    }
    data_field = data_field_map.get(field)
    if not data_field:
        return []

    # --- String fields ---
    normalized_user_input = user_input.lower().strip()
    if field in ["brokerage", "furnishing", "maintenance", "recommended_for", "water_supply", "society_type"]:
        filtered_properties = [p for p in data if str(p.get(data_field, "N/A")).lower() == normalized_user_input]

    elif field == "facilities":
        user_facilities = [normalize_facility_name(f) for f in user_input.split(',')]
        filtered_properties = [
            p for p in data
            if all(
                any(normalize_facility_name(k) == fac and v == 1
                    for k, v in p.get("Facilities", {}).items())
                for fac in user_facilities
            )
        ]


    elif field == "nearby_amenities":
        user_facilities = [normalize_facility_name(f) for f in user_input.split(',')]
        filtered_properties = [
            p for p in data
            if all(
                any(normalize_facility_name(k) == fac and v == 1
                    for k, v in p.get("Nearby_Amenities", {}).items())
                for fac in user_facilities
            )
        ]

    elif field == "room_type":
        filtered_properties = [p for p in data if normalize_room_name(p.get("Room_Details", {}).get("Rooms", "")) == normalized_user_input]

    elif field == "property_type":
        filtered_properties = [p for p in data if normalize_property_type_name(p.get("Room_Details", {}).get("Type", "")) == normalized_user_input]

    elif field == "area":
        filtered_properties = [p for p in data if normalize_area_name(p.get("Area", "N/A")) == normalize_area_name(user_input)]

    elif field == "zone":
        filtered_properties = [p for p in data if normalize_zone_name(p.get("Zone", "N/A")) == normalize_zone_name(user_input)]

    elif field == "id":
        filtered_properties = [p for p in data if str(p.get(data_field)) == user_input.strip()]

    else:
        try:
            val = get_numeric_value(user_input)
    
            if user_input.startswith("below"):
                filtered_properties = [
                    p for p in data
                    if get_numeric_value(p.get(data_field)) is not None
                    and get_numeric_value(p.get(data_field)) < val
                ]
            elif user_input.startswith("above"):
                filtered_properties = [
                    p for p in data
                    if get_numeric_value(p.get(data_field)) is not None
                    and get_numeric_value(p.get(data_field)) > val
                ]
            elif user_input.startswith("between"):
                nums = re.findall(r"\d+", user_input)
                if len(nums) == 2:
                    low, high = int(nums[0]), int(nums[1])
                    filtered_properties = [
                        p for p in data
                        if get_numeric_value(p.get(data_field)) is not None
                        and low <= get_numeric_value(p.get(data_field)) <= high
                    ]
            else:
                filtered_properties = [
                    p for p in data
                    if get_numeric_value(p.get(data_field)) == val
                ]
    
        except Exception:
            return []

    return filtered_properties

# --- Format results ---
def format_property(prop):
    property_id = prop.get('property_id', 'N/A')
    rent_price = prop.get('Rent_Price', 'N/A')
    size = prop.get('Size_In_Sqft', 'Unknown')
    carpet_area = prop.get('Carpet_Area_Sqft', 'Unknown')
    security_deposit = prop.get('Security_Deposite', 'N/A')
    brokerage = prop.get('Brokerage', 'N/A')
    furnishing_status = prop.get('Furnishing_Status', 'N/A')
    amenities = prop.get('Number_Of_Amenities',0)
    age = prop.get('Property_Age', 'Unknown')
    area = prop.get('Area', 'N/A')
    zone = prop.get('Zone', 'N/A')
    bedrooms = prop.get('Bedrooms', 'N/A')
    bathrooms = prop.get('Bathrooms', 'N/A')
    balcony = prop.get('Balcony', 'N/A')
    floor_no = prop.get('Floor_No', 'N/A')
    total_floors = prop.get('Total_floors_In_Building', 'N/A')
    maintenance = prop.get('Maintenance_Charge', 'N/A')
    recommended_for = prop.get('Recommended_For', 'N/A')
    water_supply = prop.get('Water_Supply_Type', 'N/A')
    society_type = prop.get('Society_Type', 'N/A')
    road_connectivity = prop.get('Road_Connectivity', 'N/A')
    facilities_list = [k.replace("_", " ").title() for k, v in prop.get("Facilities", {}).items() if v == 1]
    facilities = ', '.join(facilities_list) if facilities_list else 'None'
    nearby_amenities_list = [k.replace("_", " ").title() for k, v in prop.get("Nearby_Amenities", {}).items() if v == 1]
    nearby_amenities = ', '.join(nearby_amenities_list) if nearby_amenities_list else 'None'
    rooms = prop.get("Room_Details", {}).get("Rooms", "N/A")
    property_type = prop.get("Room_Details", {}).get("Type", "N/A")

    return (
        f"ID: {property_id} | Rent: ₹{rent_price} | Size: {size} sqft | Carpet Area: {carpet_area} sqft\n"
        f"Rooms: {rooms} | Property Type: {property_type} | Bedrooms: {bedrooms} | Bathrooms: {bathrooms} | Balcony: {balcony}\n"
        f"Furnishing: {furnishing_status} | Security Deposit: ₹{security_deposit} | Brokerage: {brokerage}\n"
        f"Amenities: {amenities}\n"
        f"Facilities: {facilities}\n"
        f"Nearby Amenities: {nearby_amenities}\n"
        f"Floor: {floor_no}/{total_floors} | Maintenance: {maintenance} | Recommended For: {recommended_for}\n"
        f"Water Supply: {water_supply} | Society: {society_type} | Road Connectivity: {road_connectivity} km\n"
        f"Age: {age} years | Area: {area} | Zone: {zone}\n"
        f"----------------------------------------"
    )

# --- The existing property search chatbot logic, now the 'inner' chatbot ---
def property_search_chatbot():
    print("Welcome to Property Search Chatbot!")
    print("\nSearch Options:")
    print(
        "1. Size (sqft)\n2. Carpet Area (sqft)\n3. Age of Property\n4. Brokerage (yes/no)\n5. Property ID (exact match)\n"
        "6. Amenities\n7. Furnishing Status\n8. Security Deposit\n9. Rent Price\n10. Area\n11. Zone\n"
        "12. Bedrooms\n13. Bathrooms\n14. Balcony\n15. Floor Number\n16. Total Floors\n17. Maintenance Charge\n"
        "18. Recommended For\n19. Water Supply Type\n20. Society Type\n21. Road Connectivity\n22. Facilities\n"
        "23. Nearby Amenities\n24. Room Type (e.g., 1 BHK)\n25. Property Type (e.g., Flat)\n"
    )
    print("💡 You can combine multiple search fields using '+' or a comma.")
    print("Example: 9+10 (Rent + Area) or 'rent, area'")
    print("For numeric values, you can use 'above 1000' or 'above one thousand', 'below 5000', 'between 1000 and 5000'.")
    print("For facilities/amenities, separate multiple options with a comma (e.g., 'Gym,Lift').")
    print("Type 'back' to return to the main menu.")

    CATEGORY_OPTIONS = {
    "brokerage": sorted(list(set(str(p.get("Brokerage", "N/A")).lower() for p in properties_data))),
    "furnishing": sorted(list(set(str(p.get("Furnishing_Status", "N/A")).lower() for p in properties_data))),
    "maintenance": sorted(list(set(str(p.get("Maintenance_Charge", "N/A")).lower() for p in properties_data))),
    "recommended_for": sorted(list(set(str(p.get("Recommended_For", "N/A")).lower() for p in properties_data))),
    "water_supply": sorted(list(set(str(p.get("Water_Supply_Type", "N/A")).lower() for p in properties_data))),
    "society_type": sorted(list(set(str(p.get("Society_Type", "N/A")).lower() for p in properties_data))),
    "area": ALL_AREAS,
    "zone": ALL_ZONES,
    "room_type": ALL_ROOM_TYPES,
    "property_type": ALL_PROPERTY_TYPES,
    "facilities": ALL_FACILITIES,
    "nearby_amenities": ALL_NEARBY_AMENITIES
    }

    # Map for verbal and numerical input for search fields
    search_map = {
        "1": "size", "size": "size",
        "2": "carpet", "carpet area": "carpet",
        "3": "age", "age of property": "age",
        "4": "brokerage",
        "5": "id", "property id": "id",
        "6": "amenities",
        "7": "furnishing", "furnishing status": "furnishing",
        "8": "security", "security deposit": "security",
        "9": "rent", "rent price": "rent",
        "10": "area",
        "11": "zone",
        "12": "bedrooms",
        "13": "bathrooms",
        "14": "balcony",
        "15": "floor_no", "floor number": "floor_no",
        "16": "total_floors", "total floors": "total_floors",
        "17": "maintenance", "maintenance charge": "maintenance",
        "18": "recommended_for", "recommended for": "recommended_for",
        "19": "water_supply", "water supply type": "water_supply",
        "20": "society_type", "society type": "society_type",
        "21": "road_connectivity", "road connectivity": "road_connectivity",
        "22": "facilities",
        "23": "nearby_amenities", "nearby amenities": "nearby_amenities",
        "24": "room_type", "room type": "room_type",
        "25": "property_type", "property type": "property_type"
    }

    while True:
        field_input = input("\nEnter the search field(s) (e.g., 'rent, area' or '9+10') or 'back': ").strip().lower()
        if field_input == "back":
            print("Returning to main menu.")
            break
        
        # Split input by '+' or ','
        field_tokens = re.split(r'[+,]', field_input)
        
        selected_fields = []
        is_valid_input = True
        for token in field_tokens:
            token = token.strip()
            if token in search_map:
                selected_fields.append(search_map[token])
            else:
                print(f"❌ Invalid field input: '{token}'. Please use a valid number or name from the list.")
                is_valid_input = False
                break
        
        if not is_valid_input:
            continue

        combined_filters = {}
        for field in selected_fields:
            if field in CATEGORY_OPTIONS and CATEGORY_OPTIONS[field]:
                options = CATEGORY_OPTIONS[field]
                print(f"\nAvailable options for {field.replace('_',' ').title()}:")
                for idx, option in enumerate(options, start=1):
                    print(f"{idx}. {option}")
                
                choice = input(f"Enter {field.replace('_',' ').title()} value (choose number or type value): ").strip().lower()
                
                # If user entered a number, map to option
                if choice.isdigit():
                    choice_idx = int(choice) - 1
                    if 0 <= choice_idx < len(options):
                        user_input = options[choice_idx]
                    else:
                        print("❌ Invalid choice, defaulting to your raw input.")
                        user_input = choice
                else:
                    user_input = choice
            else:
                user_input = input(f"Enter {field.replace('_',' ').title()} value: ").strip()
            
            combined_filters[field] = user_input


        # Special case for 'id'
        if "id" in combined_filters:
            prop_id = combined_filters["id"]
            prop = next((p for p in properties_data if str(p.get("property_id")) == prop_id), None)
            if prop:
                print("\n✅ Property Found:")
                print(format_property(prop))
            else:
                print("❌ Property not found.")
            continue
        
        results = properties_data
        for field, value in combined_filters.items():
            results = filter_properties(value, field, results)
        
        if not results:
            print("❌ No properties found matching your combined search.")
        else:
            print(f"\n✅ Found {len(results)} properties matching your combined query.")
            grouped_results = defaultdict(list)
            for prop in results:
                property_type = prop.get("Room_Details", {}).get("Type", "Other/Unspecified Type")
                grouped_results[property_type].append(prop)
            
            for prop_type, props in grouped_results.items():
                print(f"\n--- 🏠 Property Type: {str(prop_type).title()} ({len(props)} results) ---")
                for prop in props:
                    print(format_property(prop))

# --- Main 'outer' chatbot logic ---
def main_chatbot():
    print("Welcome to the Main Chatbot!")
    print("I can help you with a few things. Here are my current commands:")
    print("1. 'search properties' - Start the property search tool.")
    print("2. 'exit' - End the conversation.")

    while True:
        user_input = input("\nWhat can I help you with? ").strip().lower()

        if user_input == 'search properties':
            # This is where the inner chatbot is called
            property_search_chatbot()
        elif user_input == 'exit':
            print("Goodbye! Thank you for using the chatbot.")
            break
        else:
            print("I'm sorry, I don't understand that command. Please type 'search properties' or 'exit'.")

if __name__ == "__main__":
    main_chatbot()
# Out:
# Welcome to the Main Chatbot!
# I can help you with a few things. Here are my current commands:
# 1. 'search properties' - Start the property search tool.
# 2. 'exit' - End the conversation.
# What can I help you with?  search properties
# Welcome to Property Search Chatbot!
#
# Search Options:
# 1. Size (sqft)
# 2. Carpet Area (sqft)
# 3. Age of Property
# 4. Brokerage (yes/no)
# 5. Property ID (exact match)
# 6. Amenities
# 7. Furnishing Status
# 8. Security Deposit
# 9. Rent Price
# 10. Area
# 11. Zone
# 12. Bedrooms
# 13. Bathrooms
# 14. Balcony
# 15. Floor Number
# 16. Total Floors
# 17. Maintenance Charge
# 18. Recommended For
# 19. Water Supply Type
# 20. Society Type
# 21. Road Connectivity
# 22. Facilities
# 23. Nearby Amenities
# 24. Room Type (e.g., 1 BHK)
# 25. Property Type (e.g., Flat)
#
# 💡 You can combine multiple search fields using '+' or a comma.
# Example: 9+10 (Rent + Area) or 'rent, area'
# For numeric values, you can use 'above 1000' or 'above one thousand', 'below 5000', 'between 1000 and 5000'.
# For facilities/amenities, separate multiple options with a comma (e.g., 'Gym,Lift').
# Type 'back' to return to the main menu.
# Enter the search field(s) (e.g., 'rent, area' or '9+10') or 'back':  size 800
# ❌ Invalid field input: 'size 800'. Please use a valid number or name from the list.
# Enter the search field(s) (e.g., 'rent, area' or '9+10') or 'back':  size
# Enter Size value:  0
# ❌ No properties found matching your combined search.
# Enter the search field(s) (e.g., 'rent, area' or '9+10') or 'back':  back
# Returning to main menu.
# What can I help you with?  exit
# Goodbye! Thank you for using the chatbot.

# %%
import json
import re
from collections import defaultdict

# --- Load properties from JSON file ---
try:
    with open("property_data.json", "r") as f:
        properties_data = json.load(f)
except FileNotFoundError:
    print("Error: 'property_data.json' not found. Please ensure the file exists.")
    properties_data = []
except json.JSONDecodeError:
    print("Error: Could not decode 'property_data.json'. Please check its format.")
    properties_data = []

# --- Helper functions for normalization ---
def normalize_area_name(area_name):
    return str(area_name).replace(" ", "").lower().strip()

def normalize_zone_name(zone_name):
    return str(zone_name).replace(" ", "").lower().strip()

def normalize_facility_name(facility_name):
    return str(facility_name).replace(" ", "_").lower().strip()

def normalize_amenity_name(name):
    return str(name).replace(" ", "_").lower().strip()

def normalize_room_name(room_name):
    return str(room_name).replace(" ", "").lower().strip()

def normalize_property_type_name(prop_type):
    return str(prop_type).lower().strip()

def get_numeric_value(value):
    """Extract integer from strings, supporting both digits and spelled-out numbers.
        Returns None if no number is found."""
    if not value:
        return None
    
    # Dictionary for number words
    num_words = {
        'one': 1, 'two': 2, 'three': 3, 'four': 4, 'five': 5,
        'six': 6, 'seven': 7, 'eight': 8, 'nine': 9, 'ten': 10,
        'eleven': 11, 'twelve': 12, 'thirteen': 13, 'fourteen': 14,
        'fifteen': 15, 'sixteen': 16, 'seventeen': 17, 'eighteen': 18,
        'nineteen': 19, 'twenty': 20, 'thirty': 30, 'forty': 40,
        'fifty': 50, 'sixty': 60, 'seventy': 70, 'eighty': 80,
        'ninety': 90, 'hundred': 100, 'thousand': 1000, 'lakh': 100000,
        'million': 1000000, 'crore': 10000000
    }

    # Normalize the input string
    normalized_value = str(value).lower().strip().replace('-', ' ')
    
    # Check for number words first
    total_value = 0
    current_number = 0
    words = normalized_value.split()
    
    for word in words:
        if word in num_words:
            if num_words[word] >= 100:
                total_value += current_number * num_words[word]
                current_number = 0
            else:
                current_number += num_words[word]
    total_value += current_number

    # If number words were found, return the calculated value
    if total_value > 0:
        return total_value
    
    # If no number words, search for digits
    match = re.search(r"\d+", normalized_value)
    return int(match.group()) if match else None


# --- Dynamically get all unique values from the dataset ---
ALL_AREAS = sorted(
    list(set(normalize_area_name(p.get("Area", "N/A")) for p in properties_data))
)

ALL_ZONES = sorted(
    list(set(normalize_zone_name(p.get("Zone", "N/A")) for p in properties_data))
)

ALL_FACILITIES = []
for p in properties_data:
    if "Facilities" in p and isinstance(p["Facilities"], dict):
        ALL_FACILITIES = sorted(list(p["Facilities"].keys()))
        break

ALL_NEARBY_AMENITIES = []
for p in properties_data:
    if "Nearby_Amenities" in p and isinstance(p["Nearby_Amenities"], dict):
        ALL_NEARBY_AMENITIES = sorted(list(p["Nearby_Amenities"].keys()))
        break

ALL_ROOM_TYPES = sorted(
    list(set(normalize_room_name(p.get("Room_Details", {}).get("Rooms", "N/A"))
             for p in properties_data if p.get("Room_Details", {}).get("Rooms")))
)

ALL_PROPERTY_TYPES = sorted(
    list(set(normalize_property_type_name(p.get("Room_Details", {}).get("Type", "N/A"))
             for p in properties_data if p.get("Room_Details", {}).get("Type")))
)



# --- Filtering logic ---
def filter_properties(user_input, field, data):
    filtered_properties = []

    # Map search field to the actual key in properties_data
    data_field_map = {
        "size": "Size_In_Sqft", "carpet": "Carpet_Area_Sqft", "age": "Property_Age", "brokerage": "Brokerage",
        "furnishing": "Furnishing_Status", "amenities": "Number_Of_Amenities", "security": "Security_Deposite", "rent": "Rent_Price",
        "area": "Area", "zone": "Zone", "bedrooms": "Bedrooms", "bathrooms": "Bathrooms", "balcony": "Balcony",
        "floor_no": "Floor_No", "total_floors": "Total_floors_In_Building", "maintenance": "Maintenance_Charge",
        "recommended_for": "Recommended_For", "water_supply": "Water_Supply_Type", "society_type": "Society_Type",
        "road_connectivity": "Road_Connectivity", "facilities": "Facilities", "nearby_amenities": "Nearby_Amenities",
        "room_type": "Room_Details", "property_type": "Room_Details", "id": "property_id"
    }
    data_field = data_field_map.get(field)
    if not data_field:
        return []

    # --- String fields ---
    normalized_user_input = user_input.lower().strip()
    if field in ["brokerage", "furnishing", "maintenance", "recommended_for", "water_supply", "society_type"]:
        filtered_properties = [p for p in data if str(p.get(data_field, "N/A")).lower() == normalized_user_input]

    elif field == "facilities":
        user_facilities = [normalize_facility_name(f) for f in user_input.split(',')]
        filtered_properties = [
            p for p in data
            if all(
                any(normalize_facility_name(k) == fac and v == 1
                    for k, v in p.get("Facilities", {}).items())
                for fac in user_facilities
            )
        ]


    elif field == "nearby_amenities":
        user_facilities = [normalize_facility_name(f) for f in user_input.split(',')]
        filtered_properties = [
            p for p in data
            if all(
                any(normalize_facility_name(k) == fac and v == 1
                    for k, v in p.get("Nearby_Amenities", {}).items())
                for fac in user_facilities
            )
        ]

    elif field == "room_type":
        filtered_properties = [p for p in data if normalize_room_name(p.get("Room_Details", {}).get("Rooms", "")) == normalized_user_input]

    elif field == "property_type":
        filtered_properties = [p for p in data if normalize_property_type_name(p.get("Room_Details", {}).get("Type", "")) == normalized_user_input]

    elif field == "area":
        filtered_properties = [p for p in data if normalize_area_name(p.get("Area", "N/A")) == normalize_area_name(user_input)]

    elif field == "zone":
        filtered_properties = [p for p in data if normalize_zone_name(p.get("Zone", "N/A")) == normalize_zone_name(user_input)]

    elif field == "id":
        filtered_properties = [p for p in data if str(p.get(data_field)) == user_input.strip()]

    else:
        try:
            val = get_numeric_value(user_input)
    
            if user_input.startswith("below"):
                filtered_properties = [
                    p for p in data
                    if get_numeric_value(p.get(data_field)) is not None
                    and get_numeric_value(p.get(data_field)) < val
                ]
            elif user_input.startswith("above"):
                filtered_properties = [
                    p for p in data
                    if get_numeric_value(p.get(data_field)) is not None
                    and get_numeric_value(p.get(data_field)) > val
                ]
            elif user_input.startswith("between"):
                nums = re.findall(r"\d+", user_input)
                if len(nums) == 2:
                    low, high = int(nums[0]), int(nums[1])
                    filtered_properties = [
                        p for p in data
                        if get_numeric_value(p.get(data_field)) is not None
                        and low <= get_numeric_value(p.get(data_field)) <= high
                    ]
            else:
                filtered_properties = [
                    p for p in data
                    if get_numeric_value(p.get(data_field)) == val
                ]
    
        except Exception:
            return []

    return filtered_properties

# --- Format results ---
def format_property(prop):
    property_id = prop.get('property_id', 'N/A')
    rent_price = prop.get('Rent_Price', 'N/A')
    size = prop.get('Size_In_Sqft', 'Unknown')
    carpet_area = prop.get('Carpet_Area_Sqft', 'Unknown')
    security_deposit = prop.get('Security_Deposite', 'N/A')
    brokerage = prop.get('Brokerage', 'N/A')
    furnishing_status = prop.get('Furnishing_Status', 'N/A')
    amenities = prop.get('Number_Of_Amenities',0)
    age = prop.get('Property_Age', 'Unknown')
    area = prop.get('Area', 'N/A')
    zone = prop.get('Zone', 'N/A')
    bedrooms = prop.get('Bedrooms', 'N/A')
    bathrooms = prop.get('Bathrooms', 'N/A')
    balcony = prop.get('Balcony', 'N/A')
    floor_no = prop.get('Floor_No', 'N/A')
    total_floors = prop.get('Total_floors_In_Building', 'N/A')
    maintenance = prop.get('Maintenance_Charge', 'N/A')
    recommended_for = prop.get('Recommended_For', 'N/A')
    water_supply = prop.get('Water_Supply_Type', 'N/A')
    society_type = prop.get('Society_Type', 'N/A')
    road_connectivity = prop.get('Road_Connectivity', 'N/A')
    facilities_list = [k.replace("_", " ").title() for k, v in prop.get("Facilities", {}).items() if v == 1]
    facilities = ', '.join(facilities_list) if facilities_list else 'None'
    nearby_amenities_list = [k.replace("_", " ").title() for k, v in prop.get("Nearby_Amenities", {}).items() if v == 1]
    nearby_amenities = ', '.join(nearby_amenities_list) if nearby_amenities_list else 'None'
    rooms = prop.get("Room_Details", {}).get("Rooms", "N/A")
    property_type = prop.get("Room_Details", {}).get("Type", "N/A")

    return (
        f"ID: {property_id} | Rent: ₹{rent_price} | Size: {size} sqft | Carpet Area: {carpet_area} sqft\n"
        f"Rooms: {rooms} | Property Type: {property_type} | Bedrooms: {bedrooms} | Bathrooms: {bathrooms} | Balcony: {balcony}\n"
        f"Furnishing: {furnishing_status} | Security Deposit: ₹{security_deposit} | Brokerage: {brokerage}\n"
        f"Amenities: {amenities}\n"
        f"Facilities: {facilities}\n"
        f"Nearby Amenities: {nearby_amenities}\n"
        f"Floor: {floor_no}/{total_floors} | Maintenance: {maintenance} | Recommended For: {recommended_for}\n"
        f"Water Supply: {water_supply} | Society: {society_type} | Road Connectivity: {road_connectivity} km\n"
        f"Age: {age} years | Area: {area} | Zone: {zone}\n"
        f"----------------------------------------"
    )

def process_single_line_query(query):
    """Parses a single-line query like 'provide me size under 800 sqft'."""
    operator_map = {
        'under': 'below', 'less than': 'below', 'below': 'below',
        'above': 'above', 'over': 'above', 'more than': 'above',
        'between': 'between'
    }
    
    # Map from verbose names to internal names
    field_map = {
        'size': 'size', 'carpet area': 'carpet', 'age of property': 'age',
        'brokerage': 'brokerage', 'property id': 'id', 'amenities': 'amenities',
        'furnishing status': 'furnishing', 'security deposit': 'security',
        'rent price': 'rent', 'area': 'area', 'zone': 'zone',
        'bedrooms': 'bedrooms', 'bathrooms': 'bathrooms', 'balcony': 'balcony',
        'floor number': 'floor_no', 'total floors': 'total_floors',
        'maintenance charge': 'maintenance', 'recommended for': 'recommended_for',
        'water supply type': 'water_supply', 'society type': 'society_type',
        'road connectivity': 'road_connectivity', 'facilities': 'facilities',
        'nearby amenities': 'nearby_amenities', 'room type': 'room_type',
        'property type': 'property_type'
    }

    # Regex to capture the field, operator, and value.
    # It handles both single-word and multi-word fields like "carpet area"
    # and optional starting phrases like "provide me".
    match = re.search(
        r'(?:provide me|find|show me|search for)?\s*(?:\s*a)?\s*('
        + '|'.join(re.escape(k) for k in field_map.keys())
        + r')\s+('
        + '|'.join(re.escape(k) for k in operator_map.keys())
        + r')\s+(.+)$',
        query, re.IGNORECASE
    )

    if match:
        field_name = field_map.get(match.group(1).lower())
        operator = operator_map.get(match.group(2).lower())
        value = match.group(3).strip()

        # Re-format the value for the filter function
        if operator in ['below', 'above']:
            # The filter function expects "below value" or "above value"
            value = f"{operator} {value}"
        elif operator == 'between':
            # The filter function expects "between val1 and val2"
            # Split the value string to get two numbers
            between_match = re.search(r'(\d+)\s+and\s+(\d+)', value)
            if between_match:
                value = f"between {between_match.group(1)} and {between_match.group(2)}"
        
        return field_name, value
    return None, None

# --- The existing property search chatbot logic, now the 'inner' chatbot ---
def property_search_chatbot():
    print("Welcome to Property Search Chatbot!")
    print("\nSearch Options:")
    print(
        "1. Size (sqft)\n2. Carpet Area (sqft)\n3. Age of Property\n4. Brokerage (yes/no)\n5. Property ID (exact match)\n"
        "6. Amenities\n7. Furnishing Status\n8. Security Deposit\n9. Rent Price\n10. Area\n11. Zone\n"
        "12. Bedrooms\n13. Bathrooms\n14. Balcony\n15. Floor Number\n16. Total Floors\n17. Maintenance Charge\n"
        "18. Recommended For\n19. Water Supply Type\n20. Society Type\n21. Road Connectivity\n22. Facilities\n"
        "23. Nearby Amenities\n24. Room Type (e.g., 1 BHK)\n25. Property Type (e.g., Flat)\n"
    )
    print("💡 You can combine multiple search fields using '+' or a comma.")
    print("Example: 9+10 (Rent + Area) or 'rent, area'")
    print("For numeric values, you can use 'above 1000' or 'above one thousand', 'below 5000', 'between 1000 and 5000'.")
    print("💡 **New!** You can make a full query in one line. For example: 'provide me a size under 800 sqft'.")
    print("Type 'back' to return to the main menu.")

    CATEGORY_OPTIONS = {
    "brokerage": sorted(list(set(str(p.get("Brokerage", "N/A")).lower() for p in properties_data))),
    "furnishing": sorted(list(set(str(p.get("Furnishing_Status", "N/A")).lower() for p in properties_data))),
    "maintenance": sorted(list(set(str(p.get("Maintenance_Charge", "N/A")).lower() for p in properties_data))),
    "recommended_for": sorted(list(set(str(p.get("Recommended_For", "N/A")).lower() for p in properties_data))),
    "water_supply": sorted(list(set(str(p.get("Water_Supply_Type", "N/A")).lower() for p in properties_data))),
    "society_type": sorted(list(set(str(p.get("Society_Type", "N/A")).lower() for p in properties_data))),
    "area": ALL_AREAS,
    "zone": ALL_ZONES,
    "room_type": ALL_ROOM_TYPES,
    "property_type": ALL_PROPERTY_TYPES,
    "facilities": ALL_FACILITIES,
    "nearby_amenities": ALL_NEARBY_AMENITIES
    }

    # Map for verbal and numerical input for search fields
    search_map = {
        "1": "size", "size": "size",
        "2": "carpet", "carpet area": "carpet",
        "3": "age", "age of property": "age",
        "4": "brokerage",
        "5": "id", "property id": "id",
        "6": "amenities",
        "7": "furnishing", "furnishing status": "furnishing",
        "8": "security", "security deposit": "security",
        "9": "rent", "rent price": "rent",
        "10": "area",
        "11": "zone",
        "12": "bedrooms",
        "13": "bathrooms",
        "14": "balcony",
        "15": "floor_no", "floor number": "floor_no",
        "16": "total_floors", "total floors": "total_floors",
        "17": "maintenance", "maintenance charge": "maintenance",
        "18": "recommended_for", "recommended for": "recommended_for",
        "19": "water_supply", "water supply type": "water_supply",
        "20": "society_type", "society type": "society_type",
        "21": "road_connectivity", "road connectivity": "road_connectivity",
        "22": "facilities",
        "23": "nearby_amenities", "nearby amenities": "nearby_amenities",
        "24": "room_type", "room type": "room_type",
        "25": "property_type", "property type": "property_type"
    }

    while True:
        field_input = input("\nEnter your query: ").strip().lower()
        if field_input == "back":
            print("Returning to main menu.")
            break
        
        combined_filters = {}
        
        # Try to parse as a single-line query
        field, value = process_single_line_query(field_input)
        
        if field and value:
            # Single-line query detected and parsed
            combined_filters[field] = value
        else:
            # Fallback to the original multi-step process
            field_tokens = re.split(r'[+,]', field_input)
            
            selected_fields = []
            is_valid_input = True
            for token in field_tokens:
                token = token.strip()
                if token in search_map:
                    selected_fields.append(search_map[token])
                else:
                    print(f"❌ Invalid field input: '{token}'. Please use a valid number or name from the list.")
                    is_valid_input = False
                    break
            
            if not is_valid_input:
                continue

            for field in selected_fields:
                if field in CATEGORY_OPTIONS and CATEGORY_OPTIONS[field]:
                    options = CATEGORY_OPTIONS[field]
                    print(f"\nAvailable options for {field.replace('_',' ').title()}:")
                    for idx, option in enumerate(options, start=1):
                        print(f"{idx}. {option}")
                    
                    choice = input(f"Enter {field.replace('_',' ').title()} value (choose number or type value): ").strip().lower()
                    
                    # If user entered a number, map to option
                    if choice.isdigit():
                        choice_idx = int(choice) - 1
                        if 0 <= choice_idx < len(options):
                            user_input = options[choice_idx]
                        else:
                            print("❌ Invalid choice, defaulting to your raw input.")
                            user_input = choice
                    else:
                        user_input = choice
                else:
                    user_input = input(f"Enter {field.replace('_',' ').title()} value: ").strip()
                
                combined_filters[field] = user_input


        # Special case for 'id'
        if "id" in combined_filters:
            prop_id = combined_filters["id"]
            prop = next((p for p in properties_data if str(p.get("property_id")) == prop_id), None)
            if prop:
                print("\n✅ Property Found:")
                print(format_property(prop))
            else:
                print("❌ Property not found.")
            continue
        
        results = properties_data
        for field, value in combined_filters.items():
            results = filter_properties(value, field, results)
        
        if not results:
            print("❌ No properties found matching your combined search.")
        else:
            print(f"\n✅ Found {len(results)} properties matching your combined query.")
            grouped_results = defaultdict(list)
            for prop in results:
                property_type = prop.get("Room_Details", {}).get("Type", "Other/Unspecified Type")
                grouped_results[property_type].append(prop)
            
            for prop_type, props in grouped_results.items():
                print(f"\n--- 🏠 Property Type: {str(prop_type).title()} ({len(props)} results) ---")
                for prop in props:
                    print(format_property(prop))

# --- Main 'outer' chatbot logic ---
def main_chatbot():
    print("Welcome to the Main Chatbot!")
    print("I can help you with a few things. Here are my current commands:")
    print("1. 'search properties' - Start the property search tool.")
    print("2. 'exit' - End the conversation.")

    while True:
        user_input = input("\nWhat can I help you with? ").strip().lower()

        if user_input == 'search properties':
            # This is where the inner chatbot is called
            property_search_chatbot()
        elif user_input == 'exit':
            print("Goodbye! Thank you for using the chatbot.")
            break
        else:
            print("I'm sorry, I don't understand that command. Please type 'search properties' or 'exit'.")

if __name__ == "__main__":
    main_chatbot()
# Out:
# Welcome to the Main Chatbot!
# I can help you with a few things. Here are my current commands:
# 1. 'search properties' - Start the property search tool.
# 2. 'exit' - End the conversation.
# What can I help you with?  searcch properties
# I'm sorry, I don't understand that command. Please type 'search properties' or 'exit'.
# What can I help you with?  search properties
# Welcome to Property Search Chatbot!
#
# Search Options:
# 1. Size (sqft)
# 2. Carpet Area (sqft)
# 3. Age of Property
# 4. Brokerage (yes/no)
# 5. Property ID (exact match)
# 6. Amenities
# 7. Furnishing Status
# 8. Security Deposit
# 9. Rent Price
# 10. Area
# 11. Zone
# 12. Bedrooms
# 13. Bathrooms
# 14. Balcony
# 15. Floor Number
# 16. Total Floors
# 17. Maintenance Charge
# 18. Recommended For
# 19. Water Supply Type
# 20. Society Type
# 21. Road Connectivity
# 22. Facilities
# 23. Nearby Amenities
# 24. Room Type (e.g., 1 BHK)
# 25. Property Type (e.g., Flat)
#
# 💡 You can combine multiple search fields using '+' or a comma.
# Example: 9+10 (Rent + Area) or 'rent, area'
# For numeric values, you can use 'above 1000' or 'above one thousand', 'below 5000', 'between 1000 and 5000'.
# 💡 **New!** You can make a full query in one line. For example: 'provide me a size under 800 sqft'.
# Type 'back' to return to the main menu.
# Enter your query:  provide me size under 800 sqft
# ✅ Found 434 properties matching your combined query.
#
# --- 🏠 Property Type: Flat (295 results) ---
# ID: Property_2 | Rent: ₹8000.0 | Size: Total Area 700 .sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 1 BHK | Property Type: Flat | Bedrooms: 1 | Bathrooms: 1 | Balcony: 0
# Furnishing: Unfurnished | Security Deposit: ₹16000.0 | Brokerage: NO
# Amenities: 0
# Facilities: None
# Nearby Amenities: Hospital, School
# Floor: 2/3 | Maintenance: No | Recommended For: Family
# Water Supply: Both | Society: Non-Gated | Road Connectivity: 1.0 km
# Age: 0 years | Area: manewada | Zone: South Zone
# ----------------------------------------
# ID: Property_4 | Rent: ₹4000.0 | Size: Total Area 500 .sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 2 BHK | Property Type: Flat | Bedrooms: 2 | Bathrooms: 2 | Balcony: 0
# Furnishing: Fully Furnished | Security Deposit: ₹8000.0 | Brokerage: NO
# Amenities: 0
# Facilities: None
# Nearby Amenities: Airport, Hospital, Metro Station, School
# Floor: 0/0 | Maintenance: No | Recommended For: 0
# Water Supply: Borewell | Society: Non-Gated | Road Connectivity: 2.0 km
# Age: 0 years | Area: manish nagar | Zone: South Zone
# ----------------------------------------
# ID: Property_5 | Rent: ₹8500.0 | Size: Total Area 525.sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 1 BHK | Property Type: Flat | Bedrooms: 1 | Bathrooms: 1 | Balcony: 0
# Furnishing: Fully Furnished | Security Deposit: ₹17000.0 | Brokerage: NO
# Amenities: 0
# Facilities: None
# Nearby Amenities: Airport, Hospital, Metro Station, School
# Floor: 0/0 | Maintenance: No | Recommended For: 0
# Water Supply: Municipal | Society: Gated | Road Connectivity: 1.0 km
# Age: 0 years | Area: beltarodi | Zone: South Zone
# ----------------------------------------
# ID: Property_6 | Rent: ₹7000.0 | Size: Total Area 750.sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 2 BHK | Property Type: Flat | Bedrooms: 2 | Bathrooms: 2 | Balcony: 0
# Furnishing: Fully Furnished | Security Deposit: ₹14000.0 | Brokerage: NO
# Amenities: 0
# Facilities: None
# Nearby Amenities: Hospital, Mall, Metro Station, School
# Floor: 0/0 | Maintenance: No | Recommended For: 0
# Water Supply: Both | Society: Non-Gated | Road Connectivity: 2.0 km
# Age: 0 years | Area: mahal | Zone: East Zone
# ----------------------------------------
# ID: Property_32 | Rent: ₹13000.0 | Size: Total Area 650.sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 1 BHK | Property Type: Flat | Bedrooms: 1 | Bathrooms: 1 | Balcony: 2
# Furnishing: Semi Furnished | Security Deposit: ₹26000.0 | Brokerage: YES
# Amenities: 1
# Facilities: Parking
# Nearby Amenities: Hospital, Mall, Metro Station, School
# Floor: 1/3 | Maintenance: No | Recommended For: Anyone
# Water Supply: Both | Society: Non-Gated | Road Connectivity: 1.0 km
# Age: 15 years | Area: dhantoli | Zone: West Zone
# ----------------------------------------
# ID: Property_40 | Rent: ₹11000.0 | Size: Total Area 449.sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 2 BHK | Property Type: Flat | Bedrooms: 2 | Bathrooms: 2 | Balcony: 2
# Furnishing: Unfurnished | Security Deposit: ₹22000.0 | Brokerage: NO
# Amenities: 6
# Facilities: Gym, Lift, Water Supply, Kids Area, Garden, Parking
# Nearby Amenities: Hospital, Mall, Metro Station, School
# Floor: 1/4 | Maintenance: No | Recommended For: Family
# Water Supply: Borewell | Society: Non-Gated | Road Connectivity: 5.0 km
# Age: 5 years | Area: Hingna | Zone: South Zone
# ----------------------------------------
# ID: Property_45 | Rent: ₹18000.0 | Size: Total Area 700.sqft  sqft | Carpet Area: nan sqft
# Rooms: 1 BHK | Property Type: Flat | Bedrooms: 1 | Bathrooms: 1 | Balcony: 1
# Furnishing: Fully Furnished | Security Deposit: ₹36000.0 | Brokerage: YES
# Amenities: 13
# Facilities: Gated Community, Gym, Intercom, Lift, Pet Allowed, Pool, Water Supply, Gas Pipeline, Sports Facility, Kids Area, Power Backup, Garden, Parking
# Nearby Amenities: Airport, Hospital, Metro Station, School
# Floor: 6/11 | Maintenance: No | Recommended For: Anyone
# Water Supply: Both | Society: Township | Road Connectivity: 1.0 km
# Age: 5 years | Area: mihan | Zone: South Zone
# ----------------------------------------
# ID: Property_49 | Rent: ₹12000.0 | Size: Total Area 621.sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 2 BHK | Property Type: Flat | Bedrooms: 2 | Bathrooms: 2 | Balcony: 0
# Furnishing: Semi Furnished | Security Deposit: ₹24000.0 | Brokerage: NO
# Amenities: 0
# Facilities: None
# Nearby Amenities: Airport, Hospital, Metro Station, School
# Floor: 1/6 | Maintenance: No | Recommended For: Family and Bachelors
# Water Supply: Both | Society: Township | Road Connectivity: 1.0 km
# Age: 0 years | Area: gotal panjri | Zone: South Zone
# ----------------------------------------
# ID: Property_54 | Rent: ₹15000.0 | Size: Total Area 750.sqft  sqft | Carpet Area: Carpet Area 673.0 sqft sqft
# Rooms: 2 BHK | Property Type: Flat | Bedrooms: 2 | Bathrooms: 2 | Balcony: 3
# Furnishing: Semi Furnished | Security Deposit: ₹30000.0 | Brokerage: YES
# Amenities: 1
# Facilities: Parking
# Nearby Amenities: Airport, Hospital, Metro Station, School
# Floor: 9/11 | Maintenance: No | Recommended For: Family
# Water Supply: Municipal | Society: Township | Road Connectivity: 3.0 km
# Age: 3 years | Area: besa | Zone: South Zone
# ----------------------------------------
# ID: Property_56 | Rent: ₹13000.0 | Size: Total Area 516.sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 2 BHK | Property Type: Flat | Bedrooms: 2 | Bathrooms: 2 | Balcony: 1
# Furnishing: Semi Furnished | Security Deposit: ₹26000.0 | Brokerage: NO
# Amenities: 1
# Facilities: Parking
# Nearby Amenities: Hospital, Mall, Metro Station, School
# Floor: 0/0 | Maintenance: No | Recommended For: Family
# Water Supply: Borewell | Society: Township | Road Connectivity: 1.0 km
# Age: 0 years | Area: zingabai takli | Zone: West Zone
# ----------------------------------------
# ID: Property_110 | Rent: ₹10000.0 | Size: Total Area 700.sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 1 BHK | Property Type: Flat | Bedrooms: 1 | Bathrooms: 1 | Balcony: 1
# Furnishing: Semi Furnished | Security Deposit: ₹20000.0 | Brokerage: YES
# Amenities: 1
# Facilities: Parking
# Nearby Amenities: Hospital, Mall, Metro Station, School
# Floor: 3/5 | Maintenance: No | Recommended For: Family
# Water Supply: Municipal | Society: Gated | Road Connectivity: 1.0 km
# Age: 0 years | Area: manewada | Zone: South Zone
# ----------------------------------------
# ID: Property_134 | Rent: ₹12000.0 | Size: Total Area 753.sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 1 BHK | Property Type: Flat | Bedrooms: 1 | Bathrooms: 1 | Balcony: 0
# Furnishing: Semi Furnished | Security Deposit: ₹24000.0 | Brokerage: NO
# Amenities: 0
# Facilities: None
# Nearby Amenities: Bus Stop, Hospital, Mall, School
# Floor: 0/0 | Maintenance: No | Recommended For: Family
# Water Supply: Both | Society: Gated | Road Connectivity: 1.0 km
# Age: 0 years | Area: Hingna | Zone: South Zone
# ----------------------------------------
# ID: Property_135 | Rent: ₹5000.0 | Size: Total Area 600.sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 1 BHK | Property Type: Flat | Bedrooms: 1 | Bathrooms: 1 | Balcony: 1
# Furnishing: Unfurnished | Security Deposit: ₹10000.0 | Brokerage: NO
# Amenities: 0
# Facilities: None
# Nearby Amenities: Bus Stop, Hospital, Mall, Metro Station, School
# Floor: 3/4 | Maintenance: No | Recommended For: Family and Bachelors
# Water Supply: Municipal | Society: Gated | Road Connectivity: 2.0 km
# Age: 0 years | Area: Hingna | Zone: South Zone
# ----------------------------------------
# ID: Property_141 | Rent: ₹5000.0 | Size: Total Area 600.sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 1 BHK | Property Type: Flat | Bedrooms: 1 | Bathrooms: 1 | Balcony: 1
# Furnishing: Unfurnished | Security Deposit: ₹10000.0 | Brokerage: NO
# Amenities: 0
# Facilities: None
# Nearby Amenities: Bus Stop, Hospital, Metro Station, School
# Floor: 3/4 | Maintenance: No | Recommended For: Family and Bachelors
# Water Supply: Borewell | Society: Township | Road Connectivity: 1.0 km
# Age: 3 years | Area: Hingna | Zone: South Zone
# ----------------------------------------
# ID: Property_147 | Rent: ₹15000.0 | Size: Total Area 750.sqft  sqft | Carpet Area: Carpet Area 673.0 sqft sqft
# Rooms: 2 BHK | Property Type: Flat | Bedrooms: 2 | Bathrooms: 2 | Balcony: 3
# Furnishing: Semi Furnished | Security Deposit: ₹30000.0 | Brokerage: YES
# Amenities: 1
# Facilities: Parking
# Nearby Amenities: Airport, Hospital, Metro Station, School
# Floor: 9/11 | Maintenance: No | Recommended For: Family
# Water Supply: Borewell | Society: Township | Road Connectivity: 3.0 km
# Age: 3 years | Area: besa | Zone: South Zone
# ----------------------------------------
# ID: Property_149 | Rent: ₹13000.0 | Size: Total Area 516.sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 2 BHK | Property Type: Flat | Bedrooms: 2 | Bathrooms: 2 | Balcony: 1
# Furnishing: Semi Furnished | Security Deposit: ₹26000.0 | Brokerage: NO
# Amenities: 1
# Facilities: Parking
# Nearby Amenities: Hospital, Mall, Metro Station, School
# Floor: 0/0 | Maintenance: No | Recommended For: Family
# Water Supply: Both | Society: Township | Road Connectivity: 1.0 km
# Age: 0 years | Area: zingabai takli | Zone: West Zone
# ----------------------------------------
# ID: Property_202 | Rent: ₹3953.995759986536 | Size: Total Area 600 sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 1 RK | Property Type: Flat | Bedrooms: 1 | Bathrooms: 1 | Balcony: 0
# Furnishing: Semi Furnished | Security Deposit: ₹7907.991519973072 | Brokerage: NO
# Amenities: 0
# Facilities: None
# Nearby Amenities: Airport, Hospital, Metro Station, School
# Floor: 0/0 | Maintenance: No | Recommended For: 0
# Water Supply: Borewell | Society: Gated | Road Connectivity: 2.0 km
# Age: 0 years | Area: somalwada | Zone: North Zone
# ----------------------------------------
# ID: Property_205 | Rent: ₹16144.56043712713 | Size: Total Area 750 sqft  sqft | Carpet Area: Carpet Area 1200.0 sqft sqft
# Rooms: 2 BHK | Property Type: Flat | Bedrooms: 2 | Bathrooms: 3 | Balcony: 2
# Furnishing: Unfurnished | Security Deposit: ₹32289.12087425426 | Brokerage: NO
# Amenities: 4
# Facilities: Gated Community, Water Supply, Sports Facility, Parking
# Nearby Amenities: Hospital, Mall, Metro Station, School
# Floor: 0/0 | Maintenance: No | Recommended For: Family
# Water Supply: Borewell | Society: Gated | Road Connectivity: 1.0 km
# Age: 0 years | Area: manewada | Zone: East Zone
# ----------------------------------------
# ID: Property_208 | Rent: ₹21008.65130514067 | Size: Total Area 600 sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 2 BHK | Property Type: Flat | Bedrooms: 2 | Bathrooms: 2 | Balcony: 0
# Furnishing: Fully Furnished | Security Deposit: ₹42017.30261028134 | Brokerage: NO
# Amenities: 0
# Facilities: None
# Nearby Amenities: Airport, Hospital, Metro Station, School
# Floor: 0/0 | Maintenance: No | Recommended For: 0
# Water Supply: Both | Society: Gated | Road Connectivity: 1.0 km
# Age: 0 years | Area: besa | Zone: West Zone
# ----------------------------------------
# ID: Property_215 | Rent: ₹19034.97612780387 | Size: Total Area 750 sqft  sqft | Carpet Area: Carpet Area 1300.0 sqft sqft
# Rooms: 3 BHK | Property Type: Flat | Bedrooms: 3 | Bathrooms: 3 | Balcony: 4
# Furnishing: Unfurnished | Security Deposit: ₹38069.95225560774 | Brokerage: YES
# Amenities: 1
# Facilities: Parking
# Nearby Amenities: Hospital, Mall, Metro Station, School
# Floor: 3/5 | Maintenance: No | Recommended For: Family
# Water Supply: Borewell | Society: Gated | Road Connectivity: 1.0 km
# Age: 0 years | Area: manewada | Zone: North Zone
# ----------------------------------------
# ID: Property_217 | Rent: ₹9114.699186326156 | Size: Total Area 600 sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 1 RK | Property Type: Flat | Bedrooms: 1 | Bathrooms: 1 | Balcony: 0
# Furnishing: Unfurnished | Security Deposit: ₹18229.39837265231 | Brokerage: NO
# Amenities: 0
# Facilities: None
# Nearby Amenities: Hospital, Mall, Metro Station, School
# Floor: 0/0 | Maintenance: No | Recommended For: 0
# Water Supply: Borewell | Society: Non-Gated | Road Connectivity: 0.5 km
# Age: 0 years | Area: sitabuldi | Zone: South Zone
# ----------------------------------------
# ID: Property_220 | Rent: ₹46339.98359661721 | Size: Total Area 600 sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 3 BHK | Property Type: Flat | Bedrooms: 3 | Bathrooms: 3 | Balcony: 0
# Furnishing: Unfurnished | Security Deposit: ₹92679.96719323442 | Brokerage: NO
# Amenities: 0
# Facilities: None
# Nearby Amenities: Hospital, Mall, Metro Station, School
# Floor: 0/0 | Maintenance: No | Recommended For: 0
# Water Supply: Borewell | Society: Gated | Road Connectivity: 1.0 km
# Age: 0 years | Area: nandanwan | Zone: South Zone
# ----------------------------------------
# ID: Property_223 | Rent: ₹22920.82327251687 | Size: Total Area 750 sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 1 RK | Property Type: Flat | Bedrooms: 1 | Bathrooms: 2 | Balcony: 0
# Furnishing: Semi Furnished | Security Deposit: ₹45841.64654503374 | Brokerage: NO
# Amenities: 0
# Facilities: None
# Nearby Amenities: Hospital, Mall, Metro Station, School
# Floor: 3/4 | Maintenance: No | Recommended For: 0
# Water Supply: Municipal | Society: Gated | Road Connectivity: 2.0 km
# Age: 0 years | Area: ganeshpeth | Zone: South Zone
# ----------------------------------------
# ID: Property_225 | Rent: ₹34083.30942585955 | Size: Total Area 750 sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 2 BHK | Property Type: Flat | Bedrooms: 2 | Bathrooms: 2 | Balcony: 3
# Furnishing: Unfurnished | Security Deposit: ₹68166.6188517191 | Brokerage: YES
# Amenities: 3
# Facilities: Security, Parking
# Nearby Amenities: Atm, Bus Stop, Hospital, Mall, Metro Station, School
# Floor: 2/5 | Maintenance: No | Recommended For: 0
# Water Supply: Both | Society: Gated | Road Connectivity: 0.5 km
# Age: 1 years | Area: dharampeth | Zone: East Zone
# ----------------------------------------
# ID: Property_227 | Rent: ₹12143.18568128996 | Size: Total Area 600 sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 2 BHK | Property Type: Flat | Bedrooms: 2 | Bathrooms: 2 | Balcony: 3
# Furnishing: Fully Furnished | Security Deposit: ₹24286.37136257992 | Brokerage: NO
# Amenities: 0
# Facilities: None
# Nearby Amenities: Hospital, Mall, Metro Station, School
# Floor: 0/0 | Maintenance: No | Recommended For: Family
# Water Supply: Borewell | Society: Gated | Road Connectivity: 2.0 km
# Age: 2 years | Area: rameshwari | Zone: West Zone
# ----------------------------------------
# ID: Property_229 | Rent: ₹18245.74137601323 | Size: Total Area 600 sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 3 BHK | Property Type: Flat | Bedrooms: 3 | Bathrooms: 3 | Balcony: 2
# Furnishing: Unfurnished | Security Deposit: ₹36491.48275202646 | Brokerage: YES
# Amenities: 13
# Facilities: Gated Community, Gym, Intercom, Lift, Pet Allowed, Pool, Water Supply, Gas Pipeline, Sports Facility, Kids Area, Power Backup, Garden, Parking
# Nearby Amenities: Hospital, Mall, Metro Station, School
# Floor: 2/5 | Maintenance: No | Recommended For: Anyone
# Water Supply: Borewell | Society: Gated | Road Connectivity: 1.0 km
# Age: 5 years | Area: dhantoli | Zone: North Zone
# ----------------------------------------
# ID: Property_236 | Rent: ₹29834.80792148827 | Size: Total Area 750 sqft  sqft | Carpet Area: Carpet Area 1500.0 sqft sqft
# Rooms: 3 BHK | Property Type: Flat | Bedrooms: 3 | Bathrooms: 2 | Balcony: 2
# Furnishing: Fully Furnished | Security Deposit: ₹59669.61584297654 | Brokerage: YES
# Amenities: 6
# Facilities: Intercom, Lift, Water Supply, Kids Area, Power Backup, Parking
# Nearby Amenities: Hospital, Mall, Metro Station, School
# Floor: 3/5 | Maintenance: No | Recommended For: Family
# Water Supply: Both | Society: Gated | Road Connectivity: 1.0 km
# Age: 5 years | Area: jaitala | Zone: North Zone
# ----------------------------------------
# ID: Property_238 | Rent: ₹10084.33038523638 | Size: Total Area 750 sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 3 BHK | Property Type: Flat | Bedrooms: 3 | Bathrooms: 3 | Balcony: 2
# Furnishing: Unfurnished | Security Deposit: ₹20168.66077047276 | Brokerage: NO
# Amenities: 6
# Facilities: Gym, Lift, Water Supply, Kids Area, Garden, Parking
# Nearby Amenities: Hospital, Mall, Metro Station, School
# Floor: 1/4 | Maintenance: No | Recommended For: Family
# Water Supply: Borewell | Society: Gated | Road Connectivity: 5.0 km
# Age: 5 years | Area: hingna | Zone: North Zone
# ----------------------------------------
# ID: Property_239 | Rent: ₹16190.68596656697 | Size: Total Area 750 sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 2 BHK | Property Type: Flat | Bedrooms: 2 | Bathrooms: 2 | Balcony: 0
# Furnishing: Fully Furnished | Security Deposit: ₹32381.37193313394 | Brokerage: NO
# Amenities: 0
# Facilities: None
# Nearby Amenities: Bus Stop, Hospital, Mall, School
# Floor: 0/0 | Maintenance: No | Recommended For: Family
# Water Supply: Borewell | Society: Gated | Road Connectivity: 2.0 km
# Age: 0 years | Area: hingna | Zone: South Zone
# ----------------------------------------
# ID: Property_242 | Rent: ₹31393.44611999594 | Size: Total Area 750 sqft  sqft | Carpet Area: Carpet Area 1200.0 sqft sqft
# Rooms: 2 BHK | Property Type: Flat | Bedrooms: 2 | Bathrooms: 2 | Balcony: 3
# Furnishing: Semi Furnished | Security Deposit: ₹62786.89223999188 | Brokerage: YES
# Amenities: 1
# Facilities: Parking
# Nearby Amenities: Bus Stop, Hospital, Metro Station, School
# Floor: 9/16 | Maintenance: No | Recommended For: Anyone
# Water Supply: Borewell | Society: Township | Road Connectivity: 6.0 km
# Age: 1 years | Area: mihan | Zone: South Zone
# ----------------------------------------
# ID: Property_246 | Rent: ₹7180.625411557773 | Size: Total Area 600 sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 1 RK | Property Type: Flat | Bedrooms: 1 | Bathrooms: 1 | Balcony: 1
# Furnishing: Fully Furnished | Security Deposit: ₹14361.25082311555 | Brokerage: NO
# Amenities: 0
# Facilities: None
# Nearby Amenities: Bus Stop, Hospital, Metro Station, School
# Floor: 3/4 | Maintenance: No | Recommended For: Family and Bachelors
# Water Supply: Borewell | Society: Township | Road Connectivity: 1.0 km
# Age: 3 years | Area: hingna | Zone: East Zone
# ----------------------------------------
# ID: Property_249 | Rent: ₹19567.2933530052 | Size: Total Area 600 sqft  sqft | Carpet Area: Carpet Area 963.0 sqft sqft
# Rooms: 2 BHK | Property Type: Flat | Bedrooms: 2 | Bathrooms: 2 | Balcony: 2
# Furnishing: Unfurnished | Security Deposit: ₹39134.5867060104 | Brokerage: YES
# Amenities: 12
# Facilities: Gated Community, Gym, Intercom, Lift, Pet Allowed, Pool, Water Supply, Sports Facility, Kids Area, Power Backup, Garden, Parking
# Nearby Amenities: Airport, Hospital, Metro Station, School
# Floor: 7/13 | Maintenance: No | Recommended For: Family and Company
# Water Supply: Both | Society: Township | Road Connectivity: 4.0 km
# Age: 1 years | Area: beltarodi | Zone: East Zone
# ----------------------------------------
# ID: Property_251 | Rent: ₹20938.79602364807 | Size: Total Area 600 sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 1 RK | Property Type: Flat | Bedrooms: 1 | Bathrooms: 1 | Balcony: 0
# Furnishing: Semi Furnished | Security Deposit: ₹41877.59204729614 | Brokerage: NO
# Amenities: 0
# Facilities: None
# Nearby Amenities: Hospital, Mall, Metro Station, School
# Floor: 0/0 | Maintenance: No | Recommended For: 0
# Water Supply: Borewell | Society: Township | Road Connectivity: 4.0 km
# Age: 0 years | Area: manewada | Zone: West Zone
# ----------------------------------------
# ID: Property_256 | Rent: ₹18610.74030177536 | Size: Total Area 600 sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 3 BHK | Property Type: Flat | Bedrooms: 3 | Bathrooms: 3 | Balcony: 3
# Furnishing: Unfurnished | Security Deposit: ₹37221.48060355072 | Brokerage: NO
# Amenities: 4
# Facilities: Gated Community, Water Supply, Kids Area, Garden
# Nearby Amenities: Hospital, Metro Station, School
# Floor: 0/0 | Maintenance: No | Recommended For: Anyone
# Water Supply: Borewell | Society: Township | Road Connectivity: 4.0 km
# Age: 1 years | Area: kotewada | Zone: North Zone
# ----------------------------------------
# ID: Property_260 | Rent: ₹19134.6636452816 | Size: Total Area 750 sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 2 BHK | Property Type: Flat | Bedrooms: 2 | Bathrooms: 2 | Balcony: 3
# Furnishing: Unfurnished | Security Deposit: ₹38269.3272905632 | Brokerage: YES
# Amenities: 1
# Facilities: Parking
# Nearby Amenities: Airport, Hospital, Metro Station, School
# Floor: 0/0 | Maintenance: No | Recommended For: Anyone
# Water Supply: Borewell | Society: Gated | Road Connectivity: 1.0 km
# Age: 1 years | Area: pratap nagar | Zone: West Zone
# ----------------------------------------
# ID: Property_261 | Rent: ₹20948.282241558 | Size: Total Area 600 sqft  sqft | Carpet Area: Carpet Area 1169.0 sqft sqft
# Rooms: 2 BHK | Property Type: Flat | Bedrooms: 2 | Bathrooms: 2 | Balcony: 2
# Furnishing: Unfurnished | Security Deposit: ₹41896.564483116 | Brokerage: YES
# Amenities: 4
# Facilities: Pet Allowed, Water Supply, Power Backup, Parking
# Nearby Amenities: Hospital, Mall, Metro Station, School
# Floor: 0/0 | Maintenance: yes | Recommended For: Anyone
# Water Supply: Borewell | Society: Gated | Road Connectivity: 4.0 km
# Age: 5 years | Area: seminary hills | Zone: West Zone
# ----------------------------------------
# ID: Property_263 | Rent: ₹15728.31561773108 | Size: Total Area 600 sqft  sqft | Carpet Area: Carpet Area 1163.0 sqft sqft
# Rooms: 3 BHK | Property Type: Flat | Bedrooms: 3 | Bathrooms: 3 | Balcony: 2
# Furnishing: Semi Furnished | Security Deposit: ₹31456.63123546216 | Brokerage: YES
# Amenities: 3
# Facilities: Security, Parking
# Nearby Amenities: Atm, Hospital, Mall, Metro Station, School
# Floor: 0/0 | Maintenance: No | Recommended For: Anyone
# Water Supply: Municipal | Society: Gated | Road Connectivity: 0.5 km
# Age: 4 years | Area: nandanwan | Zone: East Zone
# ----------------------------------------
# ID: Property_264 | Rent: ₹32808.91255403847 | Size: Total Area 750 sqft  sqft | Carpet Area: Carpet Area 1050.0 sqft sqft
# Rooms: 2 BHK | Property Type: Flat | Bedrooms: 2 | Bathrooms: 2 | Balcony: 2
# Furnishing: Fully Furnished | Security Deposit: ₹65617.82510807694 | Brokerage: YES
# Amenities: 1
# Facilities: Parking
# Nearby Amenities: Hospital, Mall, Metro Station, School
# Floor: 0/0 | Maintenance: No | Recommended For: Anyone
# Water Supply: Municipal | Society: Township | Road Connectivity: 0.5 km
# Age: 10 years | Area: ram nagar | Zone: South Zone
# ----------------------------------------
# ID: Property_265 | Rent: ₹12972.42574096406 | Size: Total Area 750 sqft  sqft | Carpet Area: Carpet Area 900.0 sqft sqft
# Rooms: 3 BHK | Property Type: Flat | Bedrooms: 3 | Bathrooms: 3 | Balcony: 1
# Furnishing: Unfurnished | Security Deposit: ₹25944.85148192812 | Brokerage: NO
# Amenities: 2
# Facilities: Gas Pipeline, Parking
# Nearby Amenities: Airport, Hospital, Metro Station, School
# Floor: 0/0 | Maintenance: No | Recommended For: Bachelors
# Water Supply: Both | Society: Gated | Road Connectivity: 1.0 km
# Age: 0 years | Area: manish nagar | Zone: West Zone
# ----------------------------------------
# ID: Property_266 | Rent: ₹15249.90168609877 | Size: Total Area 600 sqft  sqft | Carpet Area: Carpet Area 1800.0 sqft sqft
# Rooms: 2 BHK | Property Type: Flat | Bedrooms: 2 | Bathrooms: 2 | Balcony: 3
# Furnishing: Fully Furnished | Security Deposit: ₹30499.80337219754 | Brokerage: NO
# Amenities: 3
# Facilities: Pet Allowed, Water Supply, Parking
# Nearby Amenities: Hospital, Mall, School
# Floor: 0/0 | Maintenance: No | Recommended For: Family
# Water Supply: Both | Society: Gated | Road Connectivity: 1.0 km
# Age: 0 years | Area: chandrakiran nagar | Zone: West Zone
# ----------------------------------------
# ID: Property_267 | Rent: ₹11499.42214528642 | Size: Total Area 600 sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 2 BHK | Property Type: Flat | Bedrooms: 2 | Bathrooms: 2 | Balcony: 4
# Furnishing: Unfurnished | Security Deposit: ₹22998.84429057284 | Brokerage: NO
# Amenities: 1
# Facilities: Parking
# Nearby Amenities: Airport, Hospital, Metro Station, School
# Floor: 0/0 | Maintenance: No | Recommended For: Anyone
# Water Supply: Municipal | Society: Gated | Road Connectivity: 1.0 km
# Age: 15 years | Area: duttawadi | Zone: East Zone
# ----------------------------------------
# ID: Property_268 | Rent: ₹6862.653769605749 | Size: Total Area 600 sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 3 BHK | Property Type: Flat | Bedrooms: 3 | Bathrooms: 3 | Balcony: 0
# Furnishing: Fully Furnished | Security Deposit: ₹13725.3075392115 | Brokerage: NO
# Amenities: 0
# Facilities: None
# Nearby Amenities: Bus Stop, Hospital, Metro Station, School
# Floor: 0/0 | Maintenance: No | Recommended For: 0
# Water Supply: Borewell | Society: Gated | Road Connectivity: 4.0 km
# Age: 0 years | Area: bharatwada | Zone: West Zone
# ----------------------------------------
# ID: Property_276 | Rent: ₹15272.41609170534 | Size: Total Area 750 sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 2 BHK | Property Type: Flat | Bedrooms: 2 | Bathrooms: 1 | Balcony: 1
# Furnishing: Unfurnished | Security Deposit: ₹30544.83218341068 | Brokerage: YES
# Amenities: 1
# Facilities: Parking
# Nearby Amenities: Hospital, Mall, Metro Station, School
# Floor: 0/0 | Maintenance: No | Recommended For: Anyone
# Water Supply: Borewell | Society: Township | Road Connectivity: 1.0 km
# Age: 5 years | Area: ram nagar | Zone: South Zone
# ----------------------------------------
# ID: Property_281 | Rent: ₹5084.236888411743 | Size: Total Area 600 sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 1 RK | Property Type: Flat | Bedrooms: 1 | Bathrooms: 1 | Balcony: 0
# Furnishing: Unfurnished | Security Deposit: ₹10168.47377682349 | Brokerage: NO
# Amenities: 2
# Facilities: Water Supply, Parking
# Nearby Amenities: Airport, Hospital, Metro Station, School
# Floor: 0/0 | Maintenance: No | Recommended For: Bachelors
# Water Supply: Borewell | Society: Gated | Road Connectivity: 1.0 km
# Age: 0 years | Area: Trimurti Nagar | Zone: West Zone
# ----------------------------------------
# ID: Property_283 | Rent: ₹17157.905138462 | Size: Total Area 750 sqft  sqft | Carpet Area: Carpet Area 1300.0 sqft sqft
# Rooms: 2 BHK | Property Type: Flat | Bedrooms: 2 | Bathrooms: 2 | Balcony: 4
# Furnishing: Fully Furnished | Security Deposit: ₹34315.810276924 | Brokerage: YES
# Amenities: 1
# Facilities: Parking
# Nearby Amenities: Hospital, Mall, Metro Station, School
# Floor: 0/0 | Maintenance: No | Recommended For: Anyone
# Water Supply: Borewell | Society: Gated | Road Connectivity: 1.0 km
# Age: 5 years | Area: kharbi | Zone: North Zone
# ----------------------------------------
# ID: Property_284 | Rent: ₹24365.4600673832 | Size: Total Area 750 sqft  sqft | Carpet Area: Carpet Area 1500.0 sqft sqft
# Rooms: 3 BHK | Property Type: Flat | Bedrooms: 3 | Bathrooms: 3 | Balcony: 4
# Furnishing: Semi Furnished | Security Deposit: ₹48730.9201347664 | Brokerage: YES
# Amenities: 8
# Facilities: Gated Community, Pet Allowed, Water Supply, Sports Facility, Kids Area, Power Backup, Garden, Parking
# Nearby Amenities: Hospital, Mall, Metro Station, School
# Floor: G/2 | Maintenance: No | Recommended For: Anyone
# Water Supply: Borewell | Society: Gated | Road Connectivity: 1.0 km
# Age: 5 years | Area: wardhman nagar | Zone: West Zone
# ----------------------------------------
# ID: Property_289 | Rent: ₹5247.321331773189 | Size: Total Area 600 sqft  sqft | Carpet Area: Carpet Area 150.0 sqft sqft
# Rooms: 1 RK | Property Type: Flat | Bedrooms: 1 | Bathrooms: 1 | Balcony: 0
# Furnishing: Unfurnished | Security Deposit: ₹10494.64266354638 | Brokerage: YES
# Amenities: 0
# Facilities: None
# Nearby Amenities: Airport, Hospital, Metro Station, School
# Floor: 0/0 | Maintenance: No | Recommended For: Anyone
# Water Supply: Borewell | Society: Gated | Road Connectivity: 1.0 km
# Age: 10 years | Area: besa | Zone: East Zone
# ----------------------------------------
# ID: Property_294 | Rent: ₹16494.95703927381 | Size: Total Area 750 sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 3 BHK | Property Type: Flat | Bedrooms: 3 | Bathrooms: 3 | Balcony: 3
# Furnishing: Fully Furnished | Security Deposit: ₹32989.91407854762 | Brokerage: NO
# Amenities: 5
# Facilities: Gated Community, Pool, Kids Area, Garden, Parking
# Nearby Amenities: Airport, Hospital, Metro Station, School
# Floor: 0/0 | Maintenance: No | Recommended For: Family and Company
# Water Supply: Borewell | Society: Gated | Road Connectivity: 1.0 km
# Age: 0 years | Area: mihan | Zone: South Zone
# ----------------------------------------
# ID: Property_296 | Rent: ₹28954.40955712304 | Size: Total Area 600 sqft  sqft | Carpet Area: nan sqft
# Rooms: 3 BHK | Property Type: Flat | Bedrooms: 3 | Bathrooms: 3 | Balcony: 2
# Furnishing: Fully Furnished | Security Deposit: ₹57908.81911424608 | Brokerage: NO
# Amenities: 4
# Facilities: Gated Community, Pet Allowed, Garden, Parking
# Nearby Amenities: Hospital, Mall, Metro Station, School
# Floor: 0/0 | Maintenance: No | Recommended For: Family
# Water Supply: Borewell | Society: Township | Road Connectivity: 1.0 km
# Age: 0 years | Area: manewada | Zone: West Zone
# ----------------------------------------
# ID: Property_297 | Rent: ₹4249.681968842289 | Size: Total Area 750 sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 2 BHK | Property Type: Flat | Bedrooms: 2 | Bathrooms: 2 | Balcony: 0
# Furnishing: Semi Furnished | Security Deposit: ₹8499.363937684579 | Brokerage: NO
# Amenities: 0
# Facilities: None
# Nearby Amenities: Hospital, Mall, Metro Station, School
# Floor: 0/0 | Maintenance: No | Recommended For: Bachelors
# Water Supply: Borewell | Society: Township | Road Connectivity: 2.0 km
# Age: 1 years | Area: dighori | Zone: West Zone
# ----------------------------------------
# ID: Property_303 | Rent: ₹14133.45797804697 | Size: Total Area 600 sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 2 BHK | Property Type: Flat | Bedrooms: 2 | Bathrooms: 2 | Balcony: 0
# Furnishing: Fully Furnished | Security Deposit: ₹28266.91595609394 | Brokerage: NO
# Amenities: 0
# Facilities: None
# Nearby Amenities: Hospital, Mall, Metro Station, School
# Floor: 0/0 | Maintenance: No | Recommended For: 0
# Water Supply: Borewell | Society: Gated | Road Connectivity: 2.0 km
# Age: 5 years | Area: hudkeswar | Zone: South Zone
# ----------------------------------------
# ID: Property_305 | Rent: ₹21008.45026222797 | Size: Total Area 750 sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 2 BHK | Property Type: Flat | Bedrooms: 2 | Bathrooms: 2 | Balcony: 0
# Furnishing: Semi Furnished | Security Deposit: ₹42016.90052445594 | Brokerage: YES
# Amenities: 1
# Facilities: Parking
# Nearby Amenities: Airport, Hospital, Metro Station, School
# Floor: G/2 | Maintenance: No | Recommended For: Family and Bachelors
# Water Supply: Municipal | Society: Gated | Road Connectivity: 1.0 km
# Age: 8 years | Area: narendra nagar extension | Zone: South Zone
# ----------------------------------------
# ID: Property_308 | Rent: ₹9842.506859939058 | Size: Total Area 750 sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 2 BHK | Property Type: Flat | Bedrooms: 2 | Bathrooms: 2 | Balcony: 1
# Furnishing: Semi Furnished | Security Deposit: ₹19685.01371987812 | Brokerage: YES
# Amenities: 1
# Facilities: Parking
# Nearby Amenities: Hospital, Mall, Metro Station, School
# Floor: 3/5 | Maintenance: No | Recommended For: Family
# Water Supply: Municipal | Society: Gated | Road Connectivity: 1.0 km
# Age: 0 years | Area: manewada | Zone: West Zone
# ----------------------------------------
# ID: Property_315 | Rent: ₹12254.6626833525 | Size: Total Area 750 sqft  sqft | Carpet Area: Carpet Area 1000.0 sqft sqft
# Rooms: 3 BHK | Property Type: Flat | Bedrooms: 3 | Bathrooms: 3 | Balcony: 0
# Furnishing: Semi Furnished | Security Deposit: ₹24509.325366705 | Brokerage: NO
# Amenities: 0
# Facilities: None
# Nearby Amenities: Hospital, Mall, Metro Station, School
# Floor: 0/0 | Maintenance: No | Recommended For: Family and Bachelors
# Water Supply: Borewell | Society: Gated | Road Connectivity: 1.0 km
# Age: 5 years | Area: mahal | Zone: North Zone
# ----------------------------------------
# ID: Property_317 | Rent: ₹12457.31974881262 | Size: Total Area 600 sqft  sqft | Carpet Area: Carpet Area 500.0 sqft sqft
# Rooms: 2 BHK | Property Type: Flat | Bedrooms: 2 | Bathrooms: 2 | Balcony: 1
# Furnishing: Fully Furnished | Security Deposit: ₹24914.63949762524 | Brokerage: NO
# Amenities: 1
# Facilities: Gas Pipeline
# Nearby Amenities: Hospital, Mall, Metro Station, School
# Floor: 2/2 | Maintenance: No | Recommended For: Family and Bachelors
# Water Supply: Borewell | Society: Gated | Road Connectivity: 1.0 km
# Age: 8 years | Area: rameshwari | Zone: East Zone
# ----------------------------------------
# ID: Property_324 | Rent: ₹9489.697923199228 | Size: Total Area 750 sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 2 BHK | Property Type: Flat | Bedrooms: 2 | Bathrooms: 2 | Balcony: 0
# Furnishing: Unfurnished | Security Deposit: ₹18979.39584639846 | Brokerage: NO
# Amenities: 0
# Facilities: None
# Nearby Amenities: Hospital, Mall, Metro Station, School
# Floor: 0/0 | Maintenance: No | Recommended For: Family and Company
# Water Supply: Borewell | Society: Gated | Road Connectivity: 1.0 km
# Age: 0 years | Area: kalamna | Zone: South Zone
# ----------------------------------------
# ID: Property_325 | Rent: ₹27039.37114861733 | Size: Total Area 750 sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 2 BHK | Property Type: Flat | Bedrooms: 2 | Bathrooms: 2 | Balcony: 0
# Furnishing: Unfurnished | Security Deposit: ₹54078.74229723466 | Brokerage: NO
# Amenities: 0
# Facilities: None
# Nearby Amenities: Hospital, Mall, Metro Station, School
# Floor: 1/4 | Maintenance: No | Recommended For: Family and Company
# Water Supply: Borewell | Society: Gated | Road Connectivity: 3.0 km
# Age: 0 years | Area: jaripatka | Zone: North Zone
# ----------------------------------------
# ID: Property_329 | Rent: ₹23527.60850104264 | Size: Total Area 750 sqft  sqft | Carpet Area: Carpet Area 1300.0 sqft sqft
# Rooms: 2 BHK | Property Type: Flat | Bedrooms: 2 | Bathrooms: 2 | Balcony: 2
# Furnishing: Fully Furnished | Security Deposit: ₹47055.21700208528 | Brokerage: YES
# Amenities: 6
# Facilities: Intercom, Lift, Water Supply, Kids Area, Power Backup, Parking
# Nearby Amenities: Hospital, Mall, Metro Station, School
# Floor: 3/5 | Maintenance: No | Recommended For: Family
# Water Supply: Borewell | Society: Gated | Road Connectivity: 1.0 km
# Age: 5 years | Area: jaitala | Zone: South Zone
# ----------------------------------------
# ID: Property_330 | Rent: ₹17383.9116714044 | Size: Total Area 750 sqft  sqft | Carpet Area: Carpet Area 1400.0 sqft sqft
# Rooms: 1 RK | Property Type: Flat | Bedrooms: 1 | Bathrooms: 1 | Balcony: 3
# Furnishing: Semi Furnished | Security Deposit: ₹34767.8233428088 | Brokerage: YES
# Amenities: 1
# Facilities: Parking
# Nearby Amenities: Hospital, Mall, Metro Station, School
# Floor: 1/1 | Maintenance: No | Recommended For: Anyone
# Water Supply: Borewell | Society: Gated | Road Connectivity: 1.0 km
# Age: 1 years | Area: jaitala | Zone: West Zone
# ----------------------------------------
# ID: Property_332 | Rent: ₹11330.04641514734 | Size: Total Area 600 sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 3 BHK | Property Type: Flat | Bedrooms: 3 | Bathrooms: 3 | Balcony: 0
# Furnishing: Fully Furnished | Security Deposit: ₹22660.09283029468 | Brokerage: NO
# Amenities: 0
# Facilities: None
# Nearby Amenities: Bus Stop, Hospital, Mall, School
# Floor: 0/0 | Maintenance: No | Recommended For: Family
# Water Supply: Borewell | Society: Gated | Road Connectivity: 1.0 km
# Age: 0 years | Area: hingna | Zone: South Zone
# ----------------------------------------
# ID: Property_339 | Rent: ₹5010.548597509737 | Size: Total Area 750 sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 3 BHK | Property Type: Flat | Bedrooms: 3 | Bathrooms: 3 | Balcony: 1
# Furnishing: Semi Furnished | Security Deposit: ₹10021.09719501947 | Brokerage: NO
# Amenities: 0
# Facilities: None
# Nearby Amenities: Bus Stop, Hospital, Metro Station, School
# Floor: 3/4 | Maintenance: No | Recommended For: Family and Bachelors
# Water Supply: Borewell | Society: Township | Road Connectivity: 1.0 km
# Age: 3 years | Area: hingna | Zone: South Zone
# ----------------------------------------
# ID: Property_340 | Rent: ₹14994.41261973475 | Size: Total Area 750 sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 3 BHK | Property Type: Flat | Bedrooms: 3 | Bathrooms: 3 | Balcony: 0
# Furnishing: Unfurnished | Security Deposit: ₹29988.8252394695 | Brokerage: NO
# Amenities: 0
# Facilities: None
# Nearby Amenities: Airport, Hospital, Metro Station, School
# Floor: 1/6 | Maintenance: No | Recommended For: Family and Bachelors
# Water Supply: Borewell | Society: Township | Road Connectivity: 1.0 km
# Age: 0 years | Area: gotal panjri | Zone: East Zone
# ----------------------------------------
# ID: Property_350 | Rent: ₹46672.04381187608 | Size: Total Area 600 sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 2 BHK | Property Type: Flat | Bedrooms: 2 | Bathrooms: 2 | Balcony: 0
# Furnishing: Unfurnished | Security Deposit: ₹93344.08762375216 | Brokerage: NO
# Amenities: 0
# Facilities: None
# Nearby Amenities: Hospital, Metro Station, School
# Floor: 0/0 | Maintenance: No | Recommended For: Anyone
# Water Supply: Borewell | Society: Township | Road Connectivity: 2.0 km
# Age: 0 years | Area: kotewada | Zone: North Zone
# ----------------------------------------
# ID: Property_352 | Rent: ₹70647.09013891856 | Size: Total Area 600 sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 3 BHK | Property Type: Flat | Bedrooms: 3 | Bathrooms: 3 | Balcony: 5
# Furnishing: Unfurnished | Security Deposit: ₹141294.1802778371 | Brokerage: YES
# Amenities: 1
# Facilities: Parking
# Nearby Amenities: Hospital, Mall, Metro Station, School
# Floor: G/2 | Maintenance: No | Recommended For: Anyone
# Water Supply: Borewell | Society: Gated | Road Connectivity: 1.0 km
# Age: 5 years | Area: pratap nagar | Zone: North Zone
# ----------------------------------------
# ID: Property_353 | Rent: ₹19953.43511306153 | Size: Total Area 750 sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 2 BHK | Property Type: Flat | Bedrooms: 2 | Bathrooms: 2 | Balcony: 3
# Furnishing: Fully Furnished | Security Deposit: ₹39906.87022612306 | Brokerage: YES
# Amenities: 1
# Facilities: Parking
# Nearby Amenities: Airport, Hospital, Metro Station, School
# Floor: 0/0 | Maintenance: No | Recommended For: Anyone
# Water Supply: Borewell | Society: Gated | Road Connectivity: 1.0 km
# Age: 1 years | Area: pratap nagar | Zone: East Zone
# ----------------------------------------
# ID: Property_355 | Rent: ₹15182.896483877 | Size: Total Area 750 sqft  sqft | Carpet Area: Carpet Area 1055.0 sqft sqft
# Rooms: 3 BHK | Property Type: Flat | Bedrooms: 3 | Bathrooms: 3 | Balcony: 2
# Furnishing: Unfurnished | Security Deposit: ₹30365.792967754 | Brokerage: YES
# Amenities: 3
# Facilities: Pet Allowed, Water Supply, Parking
# Nearby Amenities: Hospital, Mall, Metro Station, School
# Floor: 0/0 | Maintenance: yes | Recommended For: Anyone
# Water Supply: Borewell | Society: Gated | Road Connectivity: 1.0 km
# Age: 3 years | Area: dabha | Zone: West Zone
# ----------------------------------------
# ID: Property_359 | Rent: ₹16321.50449472896 | Size: Total Area 600 sqft  sqft | Carpet Area: Carpet Area 1800.0 sqft sqft
# Rooms: 1 RK | Property Type: Flat | Bedrooms: 1 | Bathrooms: 1 | Balcony: 3
# Furnishing: Semi Furnished | Security Deposit: ₹32643.00898945792 | Brokerage: NO
# Amenities: 3
# Facilities: Pet Allowed, Water Supply, Parking
# Nearby Amenities: Hospital, Mall, School
# Floor: 0/0 | Maintenance: No | Recommended For: Family
# Water Supply: Both | Society: Gated | Road Connectivity: 1.0 km
# Age: 0 years | Area: chandrakiran nagar | Zone: West Zone
# ----------------------------------------
# ID: Property_360 | Rent: ₹13169.9471397952 | Size: Total Area 600 sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 2 BHK | Property Type: Flat | Bedrooms: 2 | Bathrooms: 2 | Balcony: 4
# Furnishing: Semi Furnished | Security Deposit: ₹26339.8942795904 | Brokerage: NO
# Amenities: 1
# Facilities: Parking
# Nearby Amenities: Airport, Hospital, Metro Station, School
# Floor: 0/0 | Maintenance: No | Recommended For: Anyone
# Water Supply: Borewell | Society: Gated | Road Connectivity: 1.0 km
# Age: 15 years | Area: duttawadi | Zone: East Zone
# ----------------------------------------
# ID: Property_363 | Rent: ₹23430.40415670084 | Size: Total Area 750 sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 3 BHK | Property Type: Flat | Bedrooms: 3 | Bathrooms: 2 | Balcony: 0
# Furnishing: Unfurnished | Security Deposit: ₹46860.80831340168 | Brokerage: NO
# Amenities: 3
# Facilities: Pet Allowed, Water Supply, Garden
# Nearby Amenities: Hospital, Mall, Metro Station, School
# Floor: 0/0 | Maintenance: No | Recommended For: Family
# Water Supply: Borewell | Society: Township | Road Connectivity: 1.0 km
# Age: 0 years | Area: omkar nagar | Zone: East Zone
# ----------------------------------------
# ID: Property_369 | Rent: ₹14104.88795271178 | Size: Total Area 600 sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 1 RK | Property Type: Flat | Bedrooms: 1 | Bathrooms: 1 | Balcony: 1
# Furnishing: Semi Furnished | Security Deposit: ₹28209.77590542356 | Brokerage: YES
# Amenities: 1
# Facilities: Parking
# Nearby Amenities: Hospital, Mall, Metro Station, School
# Floor: 0/0 | Maintenance: No | Recommended For: Anyone
# Water Supply: Borewell | Society: Gated | Road Connectivity: 1.0 km
# Age: 5 years | Area: ram nagar | Zone: North Zone
# ----------------------------------------
# ID: Property_370 | Rent: ₹10692.58234466811 | Size: Total Area 750 sqft  sqft | Carpet Area: Carpet Area 514.0 sqft sqft
# Rooms: 2 BHK | Property Type: Flat | Bedrooms: 2 | Bathrooms: 2 | Balcony: 2
# Furnishing: Semi Furnished | Security Deposit: ₹21385.16468933622 | Brokerage: YES
# Amenities: 1
# Facilities: Parking
# Nearby Amenities: Hospital, Mall, Metro Station, School
# Floor: 0/0 | Maintenance: No | Recommended For: Anyone
# Water Supply: Borewell | Society: Gated | Road Connectivity: 0.5 km
# Age: 6 years | Area: ganeshpeth | Zone: East Zone
# ----------------------------------------
# ID: Property_372 | Rent: ₹9741.8215652059 | Size: Total Area 750 sqft  sqft | Carpet Area: Carpet Area 600.0 sqft sqft
# Rooms: 1 RK | Property Type: Flat | Bedrooms: 1 | Bathrooms: 1 | Balcony: 2
# Furnishing: Semi Furnished | Security Deposit: ₹19483.6431304118 | Brokerage: YES
# Amenities: 1
# Facilities: Parking
# Nearby Amenities: Hospital, Mall, Metro Station, School
# Floor: 0/0 | Maintenance: No | Recommended For: Family
# Water Supply: Both | Society: Gated | Road Connectivity: 1.0 km
# Age: 5 years | Area: gandhibagh | Zone: West Zone
# ----------------------------------------
# ID: Property_375 | Rent: ₹15195.55334973494 | Size: Total Area 750 sqft  sqft | Carpet Area: Carpet Area 1100.0 sqft sqft
# Rooms: 1 RK | Property Type: Flat | Bedrooms: 1 | Bathrooms: 1 | Balcony: 2
# Furnishing: Fully Furnished | Security Deposit: ₹30391.10669946988 | Brokerage: NO
# Amenities: 1
# Facilities: Parking
# Nearby Amenities: Airport, Hospital, Metro Station, School
# Floor: 0/0 | Maintenance: No | Recommended For: Anyone
# Water Supply: Borewell | Society: Gated | Road Connectivity: 2.0 km
# Age: 0 years | Area: dighori | Zone: West Zone
# ----------------------------------------
# ID: Property_376 | Rent: ₹16900.10868851509 | Size: Total Area 600 sqft  sqft | Carpet Area: Carpet Area 1300.0 sqft sqft
# Rooms: 2 BHK | Property Type: Flat | Bedrooms: 2 | Bathrooms: 2 | Balcony: 4
# Furnishing: Unfurnished | Security Deposit: ₹33800.21737703018 | Brokerage: YES
# Amenities: 1
# Facilities: Parking
# Nearby Amenities: Hospital, Mall, Metro Station, School
# Floor: 0/0 | Maintenance: No | Recommended For: Anyone
# Water Supply: Borewell | Society: Township | Road Connectivity: 1.0 km
# Age: 5 years | Area: kharbi | Zone: North Zone
# ----------------------------------------
# ID: Property_377 | Rent: ₹24862.24467736596 | Size: Total Area 750 sqft  sqft | Carpet Area: Carpet Area 1500.0 sqft sqft
# Rooms: 3 BHK | Property Type: Flat | Bedrooms: 3 | Bathrooms: 3 | Balcony: 4
# Furnishing: Semi Furnished | Security Deposit: ₹49724.48935473192 | Brokerage: YES
# Amenities: 8
# Facilities: Gated Community, Pet Allowed, Water Supply, Sports Facility, Kids Area, Power Backup, Garden, Parking
# Nearby Amenities: Hospital, Mall, Metro Station, School
# Floor: G/2 | Maintenance: No | Recommended For: Anyone
# Water Supply: Both | Society: Gated | Road Connectivity: 1.0 km
# Age: 5 years | Area: wardhman nagar | Zone: West Zone
# ----------------------------------------
# ID: Property_378 | Rent: ₹10268.24984479182 | Size: Total Area 600 sqft  sqft | Carpet Area: Carpet Area 753.0 sqft sqft
# Rooms: 2 BHK | Property Type: Flat | Bedrooms: 2 | Bathrooms: 2 | Balcony: 2
# Furnishing: Semi Furnished | Security Deposit: ₹20536.49968958364 | Brokerage: YES
# Amenities: 3
# Facilities: Kids Area, Parking
# Nearby Amenities: Atm, Bus Stop, Hospital, Metro Station, School
# Floor: 0/0 | Maintenance: No | Recommended For: Anyone
# Water Supply: Borewell | Society: Gated | Road Connectivity: 0.5 km
# Age: 0 years | Area: nandanwan | Zone: West Zone
# ----------------------------------------
# ID: Property_379 | Rent: ₹45861.94578492587 | Size: Total Area 600 sqft  sqft | Carpet Area: Carpet Area 1365.0 sqft sqft
# Rooms: 1 RK | Property Type: Flat | Bedrooms: 1 | Bathrooms: 1 | Balcony: 2
# Furnishing: Fully Furnished | Security Deposit: ₹91723.89156985174 | Brokerage: YES
# Amenities: 2
# Facilities: Garden, Parking
# Nearby Amenities: Hospital, Mall, Metro Station, School
# Floor: 0/0 | Maintenance: No | Recommended For: Anyone
# Water Supply: Borewell | Society: Gated | Road Connectivity: 1.0 km
# Age: 5 years | Area: itwari | Zone: North Zone
# ----------------------------------------
# ID: Property_381 | Rent: ₹20345.90811424202 | Size: Total Area 600 sqft  sqft | Carpet Area: Carpet Area 0.0 sqft sqft
# Rooms: 2 BHK | Property Type: Flat | Bedrooms: 2 | Bathrooms: 2 | Balcony: 3
# Furnishing: Unfurnished | Security Deposit: ₹40691.81622848404 | Brokerage: NO
# Amenities: 1
# Facilities: Parking
# Nearby Amenities: Hospital, Mall, Metro Station, School
# Floor: 0/0 | Maintenance: No | Recommended For: 0
# Water Supply: Borewell | Society: Gated | Road Connectivity: 1.0 km
# Age: 0 years | Area: ashirwad nagar | Zone: West Zone
# ----------------------------------------
# ID: Property_382 | Rent: ₹4698.434087362559 | Size: Total Area 750 sqft  sqft | Carpet Area: Carpet Area 150.0 sqft sqft
# Rooms: 1 RK | Property Type: Flat | Bedrooms: 1 | Bathrooms: 1 | Balcony: 0
# Furnishing: Unfurnished | Security Deposit: ₹9396.868174725118 | Brokerage: YES
# Amenities: 0
# Facilities: None
# Nearby Amenities: Airport, Hospital, Metro Station, School
# Floor: 0/0 | Maintenance: No | Recommended For: Anyone
# ...
# Age: 3 years | Area: manewada | Zone: North Zone
# ----------------------------------------
# ID: Property_780 | Rent: ₹22000.0 | Size: Total Area 750 sqft  sqft | Carpet Area: Carpet Area 600.0 sqft sqft
# Rooms: Studio Apartment | Property Type: Studio Apartment | Bedrooms: 3 | Bathrooms: 1 | Balcony: 1
# Furnishing: Semi Furnished | Security Deposit: ₹44000.0 | Brokerage: NO
# Amenities: 1
# Facilities: Parking
# Nearby Amenities: Park, School
# Floor: 1/8 | Maintenance: yes | Recommended For: Bachelors
# Water Supply: Municipal | Society: Gated | Road Connectivity: 1.0 km
# Age: 9 years | Area: sitabuldi | Zone: South Zone
# ----------------------------------------
# ID: Property_781 | Rent: ₹15000.0 | Size: Total Area 600 sqft  sqft | Carpet Area: Carpet Area 600.0 sqft sqft
# Rooms: Studio Apartment | Property Type: Studio Apartment | Bedrooms: 3 | Bathrooms: 3 | Balcony: 0
# Furnishing: Unfurnished | Security Deposit: ₹30000.0 | Brokerage: NO
# Amenities: 8
# Facilities: Intercom, Lift, Water Supply, Gas Pipeline, Sports Facility, Kids Area, Power Backup, Parking
# Nearby Amenities: Park, School
# Floor: 4/6 | Maintenance: yes | Recommended For: Anyone
# Water Supply: Both | Society: Gated | Road Connectivity: 1.0 km
# Age: 4 years | Area: dharampeth | Zone: North Zone
# ----------------------------------------
# ID: Property_787 | Rent: ₹15000.0 | Size: Total Area 600 sqft  sqft | Carpet Area: Carpet Area 600.0 sqft sqft
# Rooms: Studio Apartment | Property Type: Studio Apartment | Bedrooms: 3 | Bathrooms: 2 | Balcony: 2
# Furnishing: Semi Furnished | Security Deposit: ₹30000.0 | Brokerage: NO
# Amenities: 4
# Facilities: Pet Allowed, Water Supply, Power Backup, Parking
# Nearby Amenities: Airport, Metro Station
# Floor: 3/3 | Maintenance: yes | Recommended For: Bachelors
# Water Supply: Municipal | Society: Non-Gated | Road Connectivity: 2.0 km
# Age: 9 years | Area: dharampeth | Zone: North Zone
# ----------------------------------------
# ID: Property_813 | Rent: ₹22000.0 | Size: Total Area 1100 sqft  sqft | Carpet Area: Carpet Area 600.0 sqft sqft
# Rooms: Studio Apartment | Property Type: Studio Apartment | Bedrooms: 1 | Bathrooms: 1 | Balcony: 1
# Furnishing: Fully Furnished | Security Deposit: ₹44000.0 | Brokerage: NO
# Amenities: 2
# Facilities: Lift, Parking
# Nearby Amenities: Park, School
# Floor: 2/8 | Maintenance: yes | Recommended For: Bachelors
# Water Supply: Both | Society: Gated | Road Connectivity: 5.0 km
# Age: 14 years | Area: manewada | Zone: West Zone
# ----------------------------------------
# ID: Property_826 | Rent: ₹15000.0 | Size: Total Area 900 sqft  sqft | Carpet Area: Carpet Area 750.0 sqft sqft
# Rooms: Studio Apartment | Property Type: Studio Apartment | Bedrooms: 2 | Bathrooms: 2 | Balcony: 2
# Furnishing: Unfurnished | Security Deposit: ₹30000.0 | Brokerage: YES
# Amenities: 1
# Facilities: Parking
# Nearby Amenities: Park, School
# Floor: 1/7 | Maintenance: yes | Recommended For: Bachelors
# Water Supply: Municipal | Society: Gated | Road Connectivity: 1.0 km
# Age: 5 years | Area: dharampeth | Zone: East Zone
# ----------------------------------------
# ID: Property_841 | Rent: ₹18000.0 | Size: Total Area 600 sqft  sqft | Carpet Area: Carpet Area 600.0 sqft sqft
# Rooms: Studio Apartment | Property Type: Studio Apartment | Bedrooms: 3 | Bathrooms: 1 | Balcony: 2
# Furnishing: Fully Furnished | Security Deposit: ₹36000.0 | Brokerage: NO
# Amenities: 2
# Facilities: Lift, Parking
# Nearby Amenities: Park, School
# Floor: 2/7 | Maintenance: yes | Recommended For: Bachelors
# Water Supply: Borewell | Society: Non-Gated | Road Connectivity: 2.0 km
# Age: 14 years | Area: sadar | Zone: South Zone
# ----------------------------------------
# ID: Property_849 | Rent: ₹18000.0 | Size: Total Area 750 sqft  sqft | Carpet Area: Carpet Area 750.0 sqft sqft
# Rooms: Studio Apartment | Property Type: Studio Apartment | Bedrooms: 2 | Bathrooms: 3 | Balcony: 0
# Furnishing: Unfurnished | Security Deposit: ₹36000.0 | Brokerage: NO
# Amenities: 8
# Facilities: Intercom, Lift, Water Supply, Gas Pipeline, Sports Facility, Kids Area, Power Backup, Parking
# Nearby Amenities: Park, School
# Floor: 3/9 | Maintenance: yes | Recommended For: Bachelors
# Water Supply: Municipal | Society: Non-Gated | Road Connectivity: 1.0 km
# Age: 12 years | Area: sitabuldi | Zone: East Zone
# ----------------------------------------
# ID: Property_858 | Rent: ₹15000.0 | Size: Total Area 750 sqft  sqft | Carpet Area: Carpet Area 600.0 sqft sqft
# Rooms: Studio Apartment | Property Type: Studio Apartment | Bedrooms: 1 | Bathrooms: 2 | Balcony: 1
# Furnishing: Semi Furnished | Security Deposit: ₹30000.0 | Brokerage: NO
# Amenities: 3
# Facilities: Gated Community, Lift, Pet Allowed
# Nearby Amenities: Park, School
# Floor: 4/5 | Maintenance: yes | Recommended For: Bachelors
# Water Supply: Borewell | Society: Gated | Road Connectivity: 1.0 km
# Age: 15 years | Area: dharampeth | Zone: North Zone
# ----------------------------------------
# ID: Property_860 | Rent: ₹15000.0 | Size: Total Area 600 sqft  sqft | Carpet Area: Carpet Area 750.0 sqft sqft
# Rooms: Studio Apartment | Property Type: Studio Apartment | Bedrooms: 1 | Bathrooms: 1 | Balcony: 1
# Furnishing: Unfurnished | Security Deposit: ₹30000.0 | Brokerage: YES
# Amenities: 0
# Facilities: None
# Nearby Amenities: Hospital, Market
# Floor: 4/5 | Maintenance: No | Recommended For: Bachelors
# Water Supply: Both | Society: Non-Gated | Road Connectivity: 5.0 km
# Age: 8 years | Area: sadar | Zone: West Zone
# ----------------------------------------
# ID: Property_864 | Rent: ₹8000.0 | Size: Total Area 1100 sqft  sqft | Carpet Area: Carpet Area 750.0 sqft sqft
# Rooms: Studio Apartment | Property Type: Studio Apartment | Bedrooms: 2 | Bathrooms: 2 | Balcony: 0
# Furnishing: Fully Furnished | Security Deposit: ₹16000.0 | Brokerage: NO
# Amenities: 4
# Facilities: Gated Community, Water Supply, Kids Area, Garden
# Nearby Amenities: Park, School
# Floor: 3/5 | Maintenance: No | Recommended For: Family
# Water Supply: Both | Society: Non-Gated | Road Connectivity: 1.0 km
# Age: 14 years | Area: shatabdi square | Zone: South Zone
# ----------------------------------------
# ID: Property_872 | Rent: ₹18000.0 | Size: Total Area 750 sqft  sqft | Carpet Area: Carpet Area 600.0 sqft sqft
# Rooms: Studio Apartment | Property Type: Studio Apartment | Bedrooms: 3 | Bathrooms: 3 | Balcony: 1
# Furnishing: Fully Furnished | Security Deposit: ₹36000.0 | Brokerage: YES
# Amenities: 4
# Facilities: Gated Community, Water Supply, Kids Area, Garden
# Nearby Amenities: Airport, Metro Station
# Floor: 1/5 | Maintenance: yes | Recommended For: Family
# Water Supply: Borewell | Society: Gated | Road Connectivity: 5.0 km
# Age: 9 years | Area: sitabuldi | Zone: West Zone
# ----------------------------------------
# ID: Property_873 | Rent: ₹18000.0 | Size: Total Area 600 sqft  sqft | Carpet Area: Carpet Area 750.0 sqft sqft
# Rooms: Studio Apartment | Property Type: Studio Apartment | Bedrooms: 1 | Bathrooms: 1 | Balcony: 0
# Furnishing: Fully Furnished | Security Deposit: ₹36000.0 | Brokerage: YES
# Amenities: 1
# Facilities: Parking
# Nearby Amenities: Park, School
# Floor: 2/8 | Maintenance: No | Recommended For: Family
# Water Supply: Both | Society: Gated | Road Connectivity: 5.0 km
# Age: 4 years | Area: sitabuldi | Zone: South Zone
# ----------------------------------------
# ID: Property_874 | Rent: ₹22000.0 | Size: Total Area 1100 sqft  sqft | Carpet Area: Carpet Area 600.0 sqft sqft
# Rooms: Studio Apartment | Property Type: Studio Apartment | Bedrooms: 3 | Bathrooms: 1 | Balcony: 0
# Furnishing: Fully Furnished | Security Deposit: ₹44000.0 | Brokerage: YES
# Amenities: 1
# Facilities: Parking
# Nearby Amenities: Hospital, Mall, School
# Floor: 1/6 | Maintenance: yes | Recommended For: Bachelors
# Water Supply: Municipal | Society: Gated | Road Connectivity: 1.0 km
# Age: 7 years | Area: manewada | Zone: North Zone
# ----------------------------------------
# ID: Property_886 | Rent: ₹8000.0 | Size: Total Area 750 sqft  sqft | Carpet Area: Carpet Area 750.0 sqft sqft
# Rooms: Studio Apartment | Property Type: Studio Apartment | Bedrooms: 1 | Bathrooms: 1 | Balcony: 0
# Furnishing: Fully Furnished | Security Deposit: ₹16000.0 | Brokerage: YES
# Amenities: 1
# Facilities: Parking
# Nearby Amenities: Hospital, Mall, School
# Floor: 2/8 | Maintenance: yes | Recommended For: Anyone
# Water Supply: Municipal | Society: Non-Gated | Road Connectivity: 1.0 km
# Age: 1 years | Area: dharampeth | Zone: East Zone
# ----------------------------------------
# ID: Property_887 | Rent: ₹15000.0 | Size: Total Area 1100 sqft  sqft | Carpet Area: Carpet Area 600.0 sqft sqft
# Rooms: Studio Apartment | Property Type: Studio Apartment | Bedrooms: 2 | Bathrooms: 2 | Balcony: 1
# Furnishing: Fully Furnished | Security Deposit: ₹30000.0 | Brokerage: NO
# Amenities: 4
# Facilities: Pet Allowed, Water Supply, Power Backup, Parking
# Nearby Amenities: Airport, Metro Station
# Floor: 3/2 | Maintenance: yes | Recommended For: Family
# Water Supply: Both | Society: Non-Gated | Road Connectivity: 2.0 km
# Age: 2 years | Area: shatabdi square | Zone: South Zone
# ----------------------------------------
# ID: Property_896 | Rent: ₹18000.0 | Size: Total Area 750 sqft  sqft | Carpet Area: Carpet Area 750.0 sqft sqft
# Rooms: Studio Apartment | Property Type: Studio Apartment | Bedrooms: 3 | Bathrooms: 3 | Balcony: 1
# Furnishing: Semi Furnished | Security Deposit: ₹36000.0 | Brokerage: NO
# Amenities: 4
# Facilities: Gated Community, Water Supply, Kids Area, Garden
# Nearby Amenities: Hospital, Mall, School
# Floor: 3/5 | Maintenance: yes | Recommended For: Family
# Water Supply: Both | Society: Non-Gated | Road Connectivity: 1.0 km
# Age: 8 years | Area: sadar | Zone: North Zone
# ----------------------------------------
# ID: Property_899 | Rent: ₹22000.0 | Size: Total Area 750 sqft  sqft | Carpet Area: Carpet Area 750.0 sqft sqft
# Rooms: Studio Apartment | Property Type: Studio Apartment | Bedrooms: 2 | Bathrooms: 1 | Balcony: 2
# Furnishing: Semi Furnished | Security Deposit: ₹44000.0 | Brokerage: NO
# Amenities: 4
# Facilities: Pet Allowed, Water Supply, Power Backup, Parking
# Nearby Amenities: Hospital, Market
# Floor: 2/10 | Maintenance: No | Recommended For: Family
# Water Supply: Both | Society: Non-Gated | Road Connectivity: 1.0 km
# Age: 12 years | Area: shatabdi square | Zone: West Zone
# ----------------------------------------
# ID: Property_901 | Rent: ₹12000.0 | Size: Total Area 600 sqft  sqft | Carpet Area: Carpet Area 750.0 sqft sqft
# Rooms: Studio Apartment | Property Type: Studio Apartment | Bedrooms: 2 | Bathrooms: 1 | Balcony: 0
# Furnishing: Semi Furnished | Security Deposit: ₹24000.0 | Brokerage: NO
# Amenities: 1
# Facilities: Parking
# Nearby Amenities: Airport, Metro Station
# Floor: 2/2 | Maintenance: yes | Recommended For: Family
# Water Supply: Borewell | Society: Non-Gated | Road Connectivity: 2.0 km
# Age: 13 years | Area: manewada | Zone: North Zone
# ----------------------------------------
# ID: Property_922 | Rent: ₹18000.0 | Size: Total Area 1100 sqft  sqft | Carpet Area: Carpet Area 600.0 sqft sqft
# Rooms: Studio Apartment | Property Type: Studio Apartment | Bedrooms: 1 | Bathrooms: 3 | Balcony: 2
# Furnishing: Unfurnished | Security Deposit: ₹36000.0 | Brokerage: NO
# Amenities: 1
# Facilities: Parking
# Nearby Amenities: Hospital, Market
# Floor: 4/8 | Maintenance: yes | Recommended For: Anyone
# Water Supply: Both | Society: Non-Gated | Road Connectivity: 1.0 km
# Age: 5 years | Area: manewada | Zone: North Zone
# ----------------------------------------
# ID: Property_923 | Rent: ₹22000.0 | Size: Total Area 900 sqft  sqft | Carpet Area: Carpet Area 600.0 sqft sqft
# Rooms: Studio Apartment | Property Type: Studio Apartment | Bedrooms: 2 | Bathrooms: 3 | Balcony: 0
# Furnishing: Semi Furnished | Security Deposit: ₹44000.0 | Brokerage: YES
# Amenities: 4
# Facilities: Pet Allowed, Water Supply, Power Backup, Parking
# Nearby Amenities: Hospital, Mall, School
# Floor: 2/2 | Maintenance: yes | Recommended For: Bachelors
# Water Supply: Both | Society: Non-Gated | Road Connectivity: 2.0 km
# Age: 2 years | Area: sadar | Zone: East Zone
# ----------------------------------------
# ID: Property_945 | Rent: ₹22000.0 | Size: Total Area 600 sqft  sqft | Carpet Area: Carpet Area 600.0 sqft sqft
# Rooms: Studio Apartment | Property Type: Studio Apartment | Bedrooms: 2 | Bathrooms: 2 | Balcony: 0
# Furnishing: Unfurnished | Security Deposit: ₹44000.0 | Brokerage: YES
# Amenities: 1
# Facilities: Parking
# Nearby Amenities: Airport, Metro Station
# Floor: 2/9 | Maintenance: No | Recommended For: Bachelors
# Water Supply: Municipal | Society: Gated | Road Connectivity: 2.0 km
# Age: 3 years | Area: dharampeth | Zone: North Zone
# ----------------------------------------
# ID: Property_958 | Rent: ₹12000.0 | Size: Total Area 750 sqft  sqft | Carpet Area: Carpet Area 750.0 sqft sqft
# Rooms: Studio Apartment | Property Type: Studio Apartment | Bedrooms: 3 | Bathrooms: 3 | Balcony: 1
# Furnishing: Fully Furnished | Security Deposit: ₹24000.0 | Brokerage: YES
# Amenities: 4
# Facilities: Pet Allowed, Water Supply, Power Backup, Parking
# Nearby Amenities: Airport, Metro Station
# Floor: 1/2 | Maintenance: No | Recommended For: Family
# Water Supply: Municipal | Society: Gated | Road Connectivity: 5.0 km
# Age: 8 years | Area: sitabuldi | Zone: North Zone
# ----------------------------------------
# ID: Property_961 | Rent: ₹15000.0 | Size: Total Area 600 sqft  sqft | Carpet Area: Carpet Area 750.0 sqft sqft
# Rooms: Studio Apartment | Property Type: Studio Apartment | Bedrooms: 1 | Bathrooms: 1 | Balcony: 1
# Furnishing: Semi Furnished | Security Deposit: ₹30000.0 | Brokerage: YES
# Amenities: 3
# Facilities: Gated Community, Lift, Pet Allowed
# Nearby Amenities: Hospital, Mall, School
# Floor: 2/5 | Maintenance: No | Recommended For: Family
# Water Supply: Municipal | Society: Gated | Road Connectivity: 5.0 km
# Age: 7 years | Area: manewada | Zone: South Zone
# ----------------------------------------
# ID: Property_969 | Rent: ₹18000.0 | Size: Total Area 750 sqft  sqft | Carpet Area: Carpet Area 600.0 sqft sqft
# Rooms: Studio Apartment | Property Type: Studio Apartment | Bedrooms: 2 | Bathrooms: 2 | Balcony: 0
# Furnishing: Fully Furnished | Security Deposit: ₹36000.0 | Brokerage: NO
# Amenities: 4
# Facilities: Gated Community, Water Supply, Kids Area, Garden
# Nearby Amenities: Airport, Metro Station
# Floor: 1/4 | Maintenance: yes | Recommended For: Bachelors
# Water Supply: Both | Society: Gated | Road Connectivity: 5.0 km
# Age: 6 years | Area: manewada | Zone: South Zone
# ----------------------------------------
# ID: Property_986 | Rent: ₹12000.0 | Size: Total Area 600 sqft  sqft | Carpet Area: Carpet Area 750.0 sqft sqft
# Rooms: Studio Apartment | Property Type: Studio Apartment | Bedrooms: 3 | Bathrooms: 2 | Balcony: 2
# Furnishing: Semi Furnished | Security Deposit: ₹24000.0 | Brokerage: YES
# Amenities: 1
# Facilities: Parking
# Nearby Amenities: Airport, Metro Station
# Floor: 4/10 | Maintenance: No | Recommended For: Anyone
# Water Supply: Both | Society: Gated | Road Connectivity: 5.0 km
# Age: 6 years | Area: sadar | Zone: East Zone
# ----------------------------------------
# ID: Property_994 | Rent: ₹18000.0 | Size: Total Area 600 sqft  sqft | Carpet Area: Carpet Area 600.0 sqft sqft
# Rooms: Studio Apartment | Property Type: Studio Apartment | Bedrooms: 3 | Bathrooms: 3 | Balcony: 1
# Furnishing: Unfurnished | Security Deposit: ₹36000.0 | Brokerage: NO
# Amenities: 1
# Facilities: Parking
# Nearby Amenities: Park, School
# Floor: 4/2 | Maintenance: yes | Recommended For: Anyone
# Water Supply: Municipal | Society: Gated | Road Connectivity: 5.0 km
# Age: 3 years | Area: sitabuldi | Zone: North Zone
# ----------------------------------------
# Enter your query:  provide me gym facilities
# ❌ Invalid field input: 'provide me gym facilities'. Please use a valid number or name from the list.
# Enter your query:  v
# ❌ Invalid field input: 'v'. Please use a valid number or name from the list.
# Enter your query:  exit
# ❌ Invalid field input: 'exit'. Please use a valid number or name from the list.
# Enter your query:  back
# Returning to main menu.
# What can I help you with?  exit
# Goodbye! Thank you for using the chatbot.
